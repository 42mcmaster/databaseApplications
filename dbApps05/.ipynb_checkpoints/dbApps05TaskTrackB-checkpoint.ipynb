# %% [markdown]
# # Task 05 - Track B: Advanced SQL Aggregations & Analysis
#
# **Course:** Database Applications Development
# **Lesson:** 05 - SQL Aggregations, Grouping, and Excel Export
#
# ---
#
# ## Instructions
#
# Complete all exercises in this notebook. Track B includes more complex queries and advanced analysis.
#
# You will:
# 1. Write advanced SQL queries with multiple aggregates
# 2. Use complex GROUP BY with multiple columns
# 3. Apply HAVING with sophisticated filters
# 4. Export 4 comprehensive datasets to Excel
# 5. Solve real-world analytical problems
#
# **Resources:**
# - All lesson materials
# - SQL Reference Guide
# - Online SQL documentation (when needed)
#
# **Submission:**
# 1. Complete all TODO sections
# 2. Ensure all queries return expected results
# 3. Verify Excel files created with correct data
# 4. Push to GitHub: `databaseApplications/dbApps05TaskTrackB.ipynb`
#
# **Challenge yourself!** 🏀📊

# %% [markdown]
# ---
#
# ## Setup

# %%
import pandas as pd
import sqlite3

# Connect to database
conn = sqlite3.connect('nba_5seasons.db')
print("✅ Connected to database")

# %% [markdown]
# ---
#
# ## Part 1: Advanced Aggregate Queries (12 queries)
#
# These queries combine multiple concepts and require careful thinking.
#
# **Skills tested:**
# - Multiple aggregates in one query
# - Calculated columns
# - CASE statements with aggregates
# - Subqueries (optional but encouraged)

# %% [markdown]
# ### Query 1: Advanced Query 1
#
# **Task:** Write a complex aggregation query.
#
# **Hint:** Combine multiple techniques.

# %%
# TODO: Write your query
query_1 = """

"""

result_1 = pd.read_sql(query_1, conn)
display(result_1.head(10))

# %% [markdown]
# ### Query 2: Advanced Query 2
#
# **Task:** Write a complex aggregation query.
#
# **Hint:** Combine multiple techniques.

# %%
# TODO: Write your query
query_2 = """

"""

result_2 = pd.read_sql(query_2, conn)
display(result_2.head(10))

# %% [markdown]
# ### Query 3: Advanced Query 3
#
# **Task:** Write a complex aggregation query.
#
# **Hint:** Combine multiple techniques.

# %%
# TODO: Write your query
query_3 = """

"""

result_3 = pd.read_sql(query_3, conn)
display(result_3.head(10))

# %% [markdown]
# ### Query 4: Advanced Query 4
#
# **Task:** Write a complex aggregation query.
#
# **Hint:** Combine multiple techniques.

# %%
# TODO: Write your query
query_4 = """

"""

result_4 = pd.read_sql(query_4, conn)
display(result_4.head(10))

# %% [markdown]
# ### Query 5: Advanced Query 5
#
# **Task:** Write a complex aggregation query.
#
# **Hint:** Combine multiple techniques.

# %%
# TODO: Write your query
query_5 = """

"""

result_5 = pd.read_sql(query_5, conn)
display(result_5.head(10))

# %% [markdown]
# ### Query 6: Advanced Query 6
#
# **Task:** Write a complex aggregation query.
#
# **Hint:** Combine multiple techniques.

# %%
# TODO: Write your query
query_6 = """

"""

result_6 = pd.read_sql(query_6, conn)
display(result_6.head(10))

# %% [markdown]
# ### Query 7: Advanced Query 7
#
# **Task:** Write a complex aggregation query.
#
# **Hint:** Combine multiple techniques.

# %%
# TODO: Write your query
query_7 = """

"""

result_7 = pd.read_sql(query_7, conn)
display(result_7.head(10))

# %% [markdown]
# ### Query 8: Advanced Query 8
#
# **Task:** Write a complex aggregation query.
#
# **Hint:** Combine multiple techniques.

# %%
# TODO: Write your query
query_8 = """

"""

result_8 = pd.read_sql(query_8, conn)
display(result_8.head(10))

# %% [markdown]
# ### Query 9: Advanced Query 9
#
# **Task:** Write a complex aggregation query.
#
# **Hint:** Combine multiple techniques.

# %%
# TODO: Write your query
query_9 = """

"""

result_9 = pd.read_sql(query_9, conn)
display(result_9.head(10))

# %% [markdown]
# ### Query 10: Advanced Query 10
#
# **Task:** Write a complex aggregation query.
#
# **Hint:** Combine multiple techniques.

# %%
# TODO: Write your query
query_10 = """

"""

result_10 = pd.read_sql(query_10, conn)
display(result_10.head(10))

# %% [markdown]
# ### Query 11: Advanced Query 11
#
# **Task:** Write a complex aggregation query.
#
# **Hint:** Combine multiple techniques.

# %%
# TODO: Write your query
query_11 = """

"""

result_11 = pd.read_sql(query_11, conn)
display(result_11.head(10))

# %% [markdown]
# ### Query 12: Advanced Query 12
#
# **Task:** Write a complex aggregation query.
#
# **Hint:** Combine multiple techniques.

# %%
# TODO: Write your query
query_12 = """

"""

result_12 = pd.read_sql(query_12, conn)
display(result_12.head(10))

# %% [markdown]
# ---
#
# ## Part 2: Multi-Level GROUP BY Queries (6 queries)
#
# Practice grouping by multiple columns for deeper analysis.

# %% [markdown]
# ### Query 13: Multi-Level Grouping
#
# **Task:** Group by multiple columns.
#
# **Hint:** Use GROUP BY col1, col2

# %%
# TODO: Write your query
query_13 = """

"""

result_13 = pd.read_sql(query_13, conn)
display(result_13)

# %% [markdown]
# ### Query 14: Multi-Level Grouping
#
# **Task:** Group by multiple columns.
#
# **Hint:** Use GROUP BY col1, col2

# %%
# TODO: Write your query
query_14 = """

"""

result_14 = pd.read_sql(query_14, conn)
display(result_14)

# %% [markdown]
# ### Query 15: Multi-Level Grouping
#
# **Task:** Group by multiple columns.
#
# **Hint:** Use GROUP BY col1, col2

# %%
# TODO: Write your query
query_15 = """

"""

result_15 = pd.read_sql(query_15, conn)
display(result_15)

# %% [markdown]
# ### Query 16: Multi-Level Grouping
#
# **Task:** Group by multiple columns.
#
# **Hint:** Use GROUP BY col1, col2

# %%
# TODO: Write your query
query_16 = """

"""

result_16 = pd.read_sql(query_16, conn)
display(result_16)

# %% [markdown]
# ### Query 17: Multi-Level Grouping
#
# **Task:** Group by multiple columns.
#
# **Hint:** Use GROUP BY col1, col2

# %%
# TODO: Write your query
query_17 = """

"""

result_17 = pd.read_sql(query_17, conn)
display(result_17)

# %% [markdown]
# ### Query 18: Multi-Level Grouping
#
# **Task:** Group by multiple columns.
#
# **Hint:** Use GROUP BY col1, col2

# %%
# TODO: Write your query
query_18 = """

"""

result_18 = pd.read_sql(query_18, conn)
display(result_18)

# %% [markdown]
# ---
#
# ## Part 3: Advanced HAVING Clauses (4 queries)
#
# Use HAVING with complex conditions.

# %% [markdown]
# ### Query 19: Advanced HAVING
#
# **Task:** Filter groups with multiple conditions.
#
# **Hint:** Use AND/OR in HAVING

# %%
# TODO: Write your query
query_19 = """

"""

result_19 = pd.read_sql(query_19, conn)
display(result_19)

# %% [markdown]
# ### Query 20: Advanced HAVING
#
# **Task:** Filter groups with multiple conditions.
#
# **Hint:** Use AND/OR in HAVING

# %%
# TODO: Write your query
query_20 = """

"""

result_20 = pd.read_sql(query_20, conn)
display(result_20)

# %% [markdown]
# ### Query 21: Advanced HAVING
#
# **Task:** Filter groups with multiple conditions.
#
# **Hint:** Use AND/OR in HAVING

# %%
# TODO: Write your query
query_21 = """

"""

result_21 = pd.read_sql(query_21, conn)
display(result_21)

# %% [markdown]
# ### Query 22: Advanced HAVING
#
# **Task:** Filter groups with multiple conditions.
#
# **Hint:** Use AND/OR in HAVING

# %%
# TODO: Write your query
query_22 = """

"""

result_22 = pd.read_sql(query_22, conn)
display(result_22)

# %% [markdown]
# ---
#
# ## Part 4: Export Complex Datasets (4 multi-sheet exports)
#
# Create comprehensive Excel files with multiple related worksheets.

# %% [markdown]
# ### Export 1: Team Analysis
#
# **Task:** Create multi-sheet Excel workbook.
#
# **Export to:** `team_analysis.xlsx`

# %%
# TODO: Write queries for multiple sheets

# Sheet 1
query_team_analysis_1 = """

"""
sheet1 = pd.read_sql(query_team_analysis_1, conn)

# Sheet 2
query_team_analysis_2 = """

"""
sheet2 = pd.read_sql(query_team_analysis_2, conn)

# Sheet 3
query_team_analysis_3 = """

"""
sheet3 = pd.read_sql(query_team_analysis_3, conn)

# Export multi-sheet workbook
with pd.ExcelWriter('team_analysis.xlsx', engine='openpyxl') as writer:
    sheet1.to_excel(writer, sheet_name='Sheet1', index=False)
    sheet2.to_excel(writer, sheet_name='Sheet2', index=False)
    sheet3.to_excel(writer, sheet_name='Sheet3', index=False)

print(f"✅ Exported to team_analysis.xlsx")

# %% [markdown]
# ### Export 2: Player Tiers
#
# **Task:** Create multi-sheet Excel workbook.
#
# **Export to:** `player_tiers.xlsx`

# %%
# TODO: Write queries for multiple sheets

# Sheet 1
query_player_tiers_1 = """

"""
sheet1 = pd.read_sql(query_player_tiers_1, conn)

# Sheet 2
query_player_tiers_2 = """

"""
sheet2 = pd.read_sql(query_player_tiers_2, conn)

# Sheet 3
query_player_tiers_3 = """

"""
sheet3 = pd.read_sql(query_player_tiers_3, conn)

# Export multi-sheet workbook
with pd.ExcelWriter('player_tiers.xlsx', engine='openpyxl') as writer:
    sheet1.to_excel(writer, sheet_name='Sheet1', index=False)
    sheet2.to_excel(writer, sheet_name='Sheet2', index=False)
    sheet3.to_excel(writer, sheet_name='Sheet3', index=False)

print(f"✅ Exported to player_tiers.xlsx")

# %% [markdown]
# ### Export 3: Game Patterns
#
# **Task:** Create multi-sheet Excel workbook.
#
# **Export to:** `game_patterns.xlsx`

# %%
# TODO: Write queries for multiple sheets

# Sheet 1
query_game_patterns_1 = """

"""
sheet1 = pd.read_sql(query_game_patterns_1, conn)

# Sheet 2
query_game_patterns_2 = """

"""
sheet2 = pd.read_sql(query_game_patterns_2, conn)

# Sheet 3
query_game_patterns_3 = """

"""
sheet3 = pd.read_sql(query_game_patterns_3, conn)

# Export multi-sheet workbook
with pd.ExcelWriter('game_patterns.xlsx', engine='openpyxl') as writer:
    sheet1.to_excel(writer, sheet_name='Sheet1', index=False)
    sheet2.to_excel(writer, sheet_name='Sheet2', index=False)
    sheet3.to_excel(writer, sheet_name='Sheet3', index=False)

print(f"✅ Exported to game_patterns.xlsx")

# %% [markdown]
# ### Export 4: Stat Leaders
#
# **Task:** Create multi-sheet Excel workbook.
#
# **Export to:** `stat_leaders.xlsx`

# %%
# TODO: Write queries for multiple sheets

# Sheet 1
query_stat_leaders_1 = """

"""
sheet1 = pd.read_sql(query_stat_leaders_1, conn)

# Sheet 2
query_stat_leaders_2 = """

"""
sheet2 = pd.read_sql(query_stat_leaders_2, conn)

# Sheet 3
query_stat_leaders_3 = """

"""
sheet3 = pd.read_sql(query_stat_leaders_3, conn)

# Export multi-sheet workbook
with pd.ExcelWriter('stat_leaders.xlsx', engine='openpyxl') as writer:
    sheet1.to_excel(writer, sheet_name='Sheet1', index=False)
    sheet2.to_excel(writer, sheet_name='Sheet2', index=False)
    sheet3.to_excel(writer, sheet_name='Sheet3', index=False)

print(f"✅ Exported to stat_leaders.xlsx")

# %% [markdown]
# ---
#
# ## Part 5: Advanced Analysis Questions
#
# Demonstrate deep understanding of aggregations and analytics.

# %% [markdown]
# ### Question 1: Query Optimization
#
# **Explain why using WHERE to filter rows before GROUP BY is more efficient than using HAVING for the same filter. Use a specific example.**
#
# *Your answer here:*

# %% [markdown]
# ### Question 2: Real-World SQL
#
# **Design a SQL aggregation query for a business problem of your choice (retail, healthcare, education, etc.). Describe the business question and write the query.**
#
# *Your answer here:*

# %% [markdown]
# ### Question 3: Data Integrity
#
# **When calculating averages with GROUP BY, what problems might occur if you don't filter for minimum sample sizes (like minimum 20 games)? Give a concrete example.**
#
# *Your answer here:*

# %% [markdown]
# ### Question 4: Aggregation Limitations
#
# **What types of questions CANNOT be answered with aggregate functions and GROUP BY? What would you need instead?**
#
# *Your answer here:*

# %% [markdown]
# ### Question 5: Excel vs SQL
#
# **You exported team statistics to Excel. List 3 types of analysis that are EASIER in Excel than SQL, and 3 that are EASIER in SQL than Excel.**
#
# *Your answer here:*

# %% [markdown]
# ---
#
# ## Verification Checklist
#
# - [ ] All 22 advanced queries completed
# - [ ] All 4 multi-sheet Excel files created
# - [ ] All analysis questions answered thoroughly
# - [ ] Queries optimized (WHERE before HAVING when possible)
# - [ ] All cells run without errors
# - [ ] Results verified for accuracy
#
# **Excel files created:**
# 1. team_analysis.xlsx (3 sheets)
# 2. player_tiers.xlsx (4 sheets)
# 3. game_patterns.xlsx (4 sheets)
# 4. stat_leaders.xlsx (4 sheets)
#
# **Total: 15 worksheets of data ready for Excel analysis!**

# %% [markdown]
# ---
#
# ## Clean Up

# %%
# Close database connection
conn.close()
print("✅ Connection closed")
print("\nExcellent work on Track B!")
print("Your advanced queries demonstrate strong SQL skills.")
print("Ready for advanced Excel analysis!")
