# %% [markdown]
# # dbApps05a Task: Basic Aggregation Queries
#
# **Course:** Database Applications Development (145085), Medina County Career Center
#
# **Topic:** Aggregate Functions — COUNT, SUM, AVG, MIN, MAX, ROUND
#
# **Objective:** Write SQL queries using aggregate functions to summarize and analyze data from the NBA database.

# %% [markdown]
# ## Setup
#
# Import libraries and connect to the NBA database.

# %%
# Import required libraries
import pandas as pd
import sqlite3

# Establish connection to the NBA database
dbConnection = sqlite3.connect('/sessions/sweet-lucid-archimedes/mnt/databaseApplicationsForGitHub/dbApps05/nba_5seasons.db')

# %% [markdown]
# ---
#
# ### Task 1: Count Total Games
#
# Write a query that counts the total number of rows in the `team_game_stats` table. This tells us how many game records we have for all teams across all seasons.

# %%
# Your code here

# %% [markdown]
# ---
#
# ### Task 2: Count Non-Null Values
#
# Count how many non-NULL values exist in the `plus_minus` column of the `team_game_stats` table. This helps identify missing data in a specific column.

# %%
# Your code here

# %% [markdown]
# ---
#
# ### Task 3: Calculate Total Points Scored
#
# Calculate the total number of points (SUM) scored across all games in the `team_game_stats` table. This represents the aggregate of the `pts` column.

# %%
# Your code here

# %% [markdown]
# ---
#
# ### Task 4: Calculate Average Points Per Game
#
# Calculate the average points scored per game (AVG of `pts`) in the `team_game_stats` table across all seasons and teams.

# %%
# Your code here

# %% [markdown]
# ---
#
# ### Task 5: Find Minimum and Maximum Points
#
# Write a query that returns both the minimum and maximum points scored in a single game from the `team_game_stats` table.

# %%
# Your code here

# %% [markdown]
# ---
#
# ### Task 6: Round Average Field Goal Percentage
#
# Calculate the average field goal percentage (AVG of `fg_pct`) from the `player_season_stats` table and round it to 2 decimal places. Use the ROUND function.

# %%
# Your code here

# %% [markdown]
# ---
#
# ### Task 7: Count Distinct Teams
#
# Count the number of distinct (unique) teams in the `team_game_stats` table using COUNT(DISTINCT team_id). This tells us how many different teams are represented in the data.

# %%
# Your code here

# %% [markdown]
# ---
#
# ### Task 8: Multiple Aggregates in One Query
#
# Write a single query that returns:
# - Total number of rebounds (SUM of `reb`)
# - Average rebounds per game (AVG of `reb`)
# - Minimum rebounds (MIN of `reb`)
# - Maximum rebounds (MAX of `reb`)
#
# All from the `team_game_stats` table. Give each column an alias for clarity.

# %%
# Your code here

# %% [markdown]
# ---
#
# ### Task 9: Average Three-Point Percentage by Season
#
# Calculate the average three-point field goal percentage (AVG of `fg3_pct`) for each season from the `player_season_stats` table. Return the season and the rounded average (2 decimal places) with an alias. Order by season.

# %%
# Your code here

# %% [markdown]
# ---
#
# ### Task 10: Total Games Played by Players in a Season
#
# From the `player_season_stats` table, calculate:
# - Total games played (SUM of `gp`) across all players
# - Average games played (AVG of `gp`) per player
# - The player with minimum games played (MIN of `gp`)
# - The player with maximum games played (MAX of `gp`)
#
# Use column aliases for clarity.

# %%
# Your code here
