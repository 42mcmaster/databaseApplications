# %% [markdown]
# # dbApps03 DIY Task: Databases in Practice
# **Lesson:** 03 — Introduction to Databases

# %% [markdown]
# ## Part 1: Concept Questions
#
# ### Task 1.1: Data vs. Information
# Explain the difference between data and information. Give your own example.

# %% [markdown]
# **Your answer:**

# %% [markdown]
# ### Task 1.2: Advantages of Databases
# Name 3 advantages of using a database instead of CSV files.

# %% [markdown]
# **Your answer:**

# %% [markdown]
# ### Task 1.3: What is DBMS?
# What does DBMS stand for? Give 2 examples of DBMS software.

# %% [markdown]
# **Your answer:**

# %% [markdown]
# ### Task 1.4: What is SQL?
# Explain what SQL is in one sentence.

# %% [markdown]
# **Your answer:**

# %% [markdown]
# ## Part 2: Build & Query
#
# ### Task 2.1: Import Libraries and Load Data
# Import pandas and sqlite3. Load the Titanic CSV file.

# %%
# Import pandas and sqlite3, then load the Titanic CSV file

# %% [markdown]
# ### Task 2.2: Create Database and Table
# Create a database called "titanic_diy.db" and save the data as "passengers" table.

# %%
# Create SQLite connection, save DataFrame as 'passengers' table, and print confirmation

# %% [markdown]
# ### Task 2.3: Query - Name, Sex, Age, Fare (First 15 Passengers)
# Write a query that returns the name, sex, age, and fare for the first 15 passengers.

# %%
# Execute SQL query: SELECT name, sex, age, fare FROM passengers LIMIT 15

# %% [markdown]
# ### Task 2.4: Query - Name and Survived (First 20 Passengers)
# Write a query that returns only the name and survived columns for the first 20 passengers.

# %%
# Execute SQL query: SELECT name, survived FROM passengers LIMIT 20

# %% [markdown]
# ### Task 2.5: Check Column Data Types
# Use PRAGMA to check the column info. Answer the questions in the markdown cell below.

# %%
# Execute PRAGMA table_info(passengers) to see all columns and their data types

# %% [markdown]
# **Questions:**
# - What data type is the "fare" column? ___________
# - What data type is the "name" column? ___________

# %% [markdown]
# ## Part 3: Reflection
#
# ### Task 3.1: CSV vs. Database
# We now have the same Titanic data in THREE forms: CSV file, pandas DataFrame, and SQLite database. Why might we want to use a database instead of just keeping the CSV?

# %% [markdown]
# **Your answer:**

# %% [markdown]
# ### Task 3.2: One Interesting Thing
# What is one thing from this lesson that you found interesting or surprising?

# %% [markdown]
# **Your answer:**

# %% [markdown]
# ## Closing the Connection
#
# Always close your database connection when done, then commit any changes to GitHub.

# %%
# Close the database connection
