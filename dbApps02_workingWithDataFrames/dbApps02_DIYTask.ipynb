# %% [markdown]
# # dbApps02 DIY Task: Working with DataFrames
#
# **Course:** Database Applications Development
# **Lesson:** 02 — Working with DataFrames
#
# ---
#
# ## Instructions
#
# Complete all tasks below independently. Use your walkthrough notebook as a reference if you get stuck.
#
# When finished: Save → Commit → Push to GitHub

# %% [markdown]
# ## Part 1: Setup + Column Selection

# %% [markdown]
# **Task 1.1:** Import pandas and load "Titanic Dataset.csv" into a DataFrame called `titanic`.

# %%
# Import pandas library and load Titanic Dataset.csv
import pandas as pd
titanic =

# %% [markdown]
# **Task 1.2:** Create a DataFrame called `passengerBasics` with columns: name, age, sex, pclass. Display the first 8 rows.

# %%
# Select name, age, sex, pclass columns and display first 8 rows
passengerBasics = 
passengerBasics.head(8)

# %% [markdown]
# **Task 1.3:** Create a DataFrame called `ticketInfo` with columns: name, ticket, fare, cabin. Display the first 5 rows.

# %%
# Select name, ticket, fare, cabin columns and display first 5 rows
ticketInfo = 
ticketInfo.head(5)

# %% [markdown]
# ## Part 2: Filtering

# %% [markdown]
# **Task 2.1:** Create a DataFrame called `survivors` with only passengers who survived. Print how many there are.

# %%
# Filter for survived passengers (survived == 1)
survivors = 
print(f"Number of survivors: {len(survivors)}")

# %% [markdown]
# **Task 2.2:** Create a DataFrame called `children` with passengers age 12 or younger. Print how many.

# %%
# Filter for passengers age 12 or younger
children = 
print(f"Number of children (age 12 or younger): {len(children)}")

# %% [markdown]
# **Task 2.3:** Create a DataFrame called `expensiveTickets` with passengers who paid more than $100 fare. Show first 5 rows with name and fare.

# %%
# Filter for passengers with fare > 100 and display name and fare
expensiveTickets = 
expensiveTickets[['name', 'fare']].head(5)

# %% [markdown]
# **Task 2.4:** Create a DataFrame called `femaleFirstClass` with female passengers in first class (combine two conditions). Print how many.

# %%
# Filter for female passengers in first class (sex == 'female' AND pclass == 1)
femaleFirstClass = 
print(f"Number of female first class passengers: {len(femaleFirstClass)}")

# %% [markdown]
# **Task 2.5:** Create a DataFrame called `youngSurvivors` with survivors under age 18. Print how many.

# %%
# Filter for survivors (survived == 1) who are under age 18
youngSurvivors = 
print(f"Number of survivors under age 18: {len(youngSurvivors)}")

# %% [markdown]
# ## Part 3: Sorting + Stats

# %% [markdown]
# **Task 3.1:** Sort passengers by fare (highest first). Display the name and fare of the top 5 most expensive tickets.

# %%
# Sort by fare in descending order and display top 5 names and fares

# %% [markdown]
# **Task 3.2:** Calculate and print the average age of all passengers.

# %%
# Calculate average age
avgAge = 
print(f"Average age: {avgAge}")

# %% [markdown]
# **Task 3.3:** Calculate and print the average fare for each class (first, second, third — do each separately).

# %%
# Calculate average fare for class 1, class 2, and class 3 separately
avgFareClass1 = 
avgFareClass2 = 
avgFareClass3 = 

print(f"Average fare for first class: {avgFareClass1}")
print(f"Average fare for second class: {avgFareClass2}")
print(f"Average fare for third class: {avgFareClass3}")

# %% [markdown]
# **Task 3.4:** Find the youngest and oldest passenger ages. Print both.

# %%
# Find minimum and maximum ages
minAge = 
maxAge = 

print(f"Youngest passenger age: {minAge}")
print(f"Oldest passenger age: {maxAge}")

# %% [markdown]
# ## Part 4: Analysis Questions

# %% [markdown]
# **Task 4.1:** Use .value_counts() on the "embarked" column. Which port had the most passengers?

# %%
# Use value_counts() on the embarked column

# %% [markdown]
# **Answer:** Which port had the most passengers?

# %% [markdown]
# **Task 4.2:** Calculate the survival rate (what percentage survived). Hint: .mean() on the survived column gives you this as a decimal.

# %%
# Calculate survival rate using .mean() and convert to percentage
survivalRate = 
print(f"Survival rate: {survivalRate * 100:.2f}%")

# %% [markdown]
# **Task 4.3:** Did first class passengers have a higher survival rate than third class? Calculate both and compare.

# %%
# Calculate survival rate for first class and third class separately
firstClassSurvivalRate = 
thirdClassSurvivalRate = 

print(f"First class survival rate: {firstClassSurvivalRate * 100:.2f}%")
print(f"Third class survival rate: {thirdClassSurvivalRate * 100:.2f}%")

# %% [markdown]
# **Answer:** Did first class passengers have a higher survival rate?
