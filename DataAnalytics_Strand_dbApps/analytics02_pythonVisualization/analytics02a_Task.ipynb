# %% [markdown]
# # analytics02a_Task: Summarize & Chart in Python
# **Course**: Programming (CTE) | **Instructor**: Ryan McMaster
# **Medina County Career Center**
#
# Complete the exercises using pandas on `pizza_orders.csv` (same folder). Answers are deterministic.

# %% [markdown]
# ## Exercise 1: Load and Count
#
# Load `pizza_orders.csv` into `df` and set `n_rows` to the number of rows. Print it.

# %%
import pandas as pd
# Your code here
df = 
n_rows = 

print(n_rows)   # Should print 63

# %% [markdown]
# ## Exercise 2: Total Revenue
#
# Set `total` to the sum of the `line_total` column, rounded to 2 decimals. Print it.

# %%
# Your code here
total = 

print(total)   # Should print 1600.0

# %% [markdown]
# ## Exercise 3: Group by Region
#
# Set `rev` to a dict of total `line_total` per `region` (rounded to 2). Print it.
# - `df.groupby('region')['line_total'].sum().round(2).to_dict()`

# %%
# Your code here
rev = 

print(rev)   # Should print {'East': 435.0, 'North': 303.0, 'South': 363.0, 'West': 499.0}

# %% [markdown]
# ## Exercise 4: Top Region
#
# Set `top` to the name of the region with the highest total revenue. Print it.
# - Use `.idxmax()` on the grouped totals

# %%
# Your code here
top = 

print(top)   # Should print West

# %% [markdown]
# ## Exercise 5: Which Chart?
#
# You want to show the **distribution** of order totals (how many orders fall in each dollar range). Which chart type?
#
# Set `answer` to `"histogram"`, `"line"`, or `"scatter"`.

# %%
# Your code here
answer = 

print(answer)   # Should print histogram

# %% [markdown]
# ## Exercise 6: Average Quantity
#
# Set `avg_qty` to the mean of the `quantity` column, rounded to 2. Print it.

# %%
# Your code here
avg_qty = 

print(avg_qty)   # Should print 2.37
