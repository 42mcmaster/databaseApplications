# %% [markdown]
# # dbApps10 Capstone Project
#
# **Course:** Database Applications Development
#
# **Topic:** *(write your topic here)*

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import sqlite3

# Connect to database file
conn = sqlite3.connect('my_project.db')
cursor = conn.cursor()

# %% [markdown]
# ## Part 1: Design (Sub-Lesson 10a-10b)

# %% [markdown]
# ### My Topic
#
# Describe your database idea and the business rules it enforces.
# What problem are you solving? What entities and relationships are important?

# %% [markdown]
# ### ER Diagram
#
# Draw your Entity-Relationship diagram in ASCII format here.
# Show tables and their relationships (1-to-1, 1-to-many, many-to-many).

# %% [markdown]
# ### Data Dictionary
#
# List your tables, columns, data types, constraints, and keys:
#
# | Table | Column | Type | Constraints | Notes |
# |-------|--------|------|-------------|-------|
# | | | | | |

# %% [markdown]
# ## Part 2: Build (Sub-Lesson 10c)

# %% [markdown]
# ### CREATE TABLE Statements

# %%
# Create your tables here
# Remember: PRIMARY KEY, FOREIGN KEY, NOT NULL, UNIQUE, CHECK, DEFAULT constraints

# %% [markdown]
# ### INSERT Data

# %%
# Insert your records here (aim for 20+ records per main table)
# Use separate INSERT INTO statements for each record
# Example: cursor.execute("INSERT INTO tableName (col1, col2) VALUES (?, ?)", (val1, val2))

# %% [markdown]
# ### Verify Tables

# %%
# Run SELECT * from each table to verify data was inserted correctly

# %% [markdown]
# ## Part 3: Queries (Sub-Lesson 10d)

# %% [markdown]
# ### Query 1: Basic SELECT with WHERE

# %%
# Write a simple SELECT query with a WHERE clause
# Example: SELECT all customers from a specific city

# %% [markdown]
# ### Query 2: SELECT with Multiple Conditions

# %%
# Write a query with multiple conditions (AND, OR)
# Example: SELECT orders from January AND quantity > 5

# %% [markdown]
# ### Query 3: ORDER BY and LIMIT

# %%
# Write a query sorted and limited to top N results
# Example: SELECT top 5 most expensive items

# %% [markdown]
# ### Query 4: Aggregate Function (COUNT, SUM, AVG, etc.)

# %%
# Write a query using an aggregate function
# Example: SELECT COUNT(*) total_records, AVG(price) from products

# %% [markdown]
# ### Query 5: GROUP BY with Aggregate

# %%
# Write a query with GROUP BY
# Example: SELECT category, COUNT(*) count from products GROUP BY category

# %% [markdown]
# ### Query 6: GROUP BY with HAVING

# %%
# Write a query with GROUP BY and HAVING clause
# Example: SELECT category, COUNT(*) count from products GROUP BY category HAVING COUNT(*) > 10

# %% [markdown]
# ### Query 7: INNER JOIN

# %%
# Write an INNER JOIN between two tables
# Example: SELECT customer name and their orders

# %% [markdown]
# ### Query 8: LEFT JOIN

# %%
# Write a LEFT JOIN between two tables
# Example: SELECT all customers and their orders (even if no orders)

# %% [markdown]
# ### Query 9: Multi-table JOIN or JOIN + GROUP BY

# %%
# Write a more complex query with multiple JOINs and/or GROUP BY
# Example: SELECT customer name, COUNT(orders) from customers LEFT JOIN orders GROUP BY customer

# %% [markdown]
# ### Query 10: Your Choice

# %%
# Show off! Write an interesting query that demonstrates a SQL skill
# You can combine multiple concepts or find a useful business insight

# %% [markdown]
# ## Part 4: Security (Sub-Lesson 10e)

# %% [markdown]
# ### Parameterized Query Demo

# %%
# Show at least one parameterized query using ? placeholders
# This protects against SQL injection
# Example: cursor.execute("SELECT * FROM users WHERE id = ?", (userInput,))

# %% [markdown]
# ### Transaction Demo

# %%
# Show BEGIN, operations, and COMMIT
# If an error occurs, ROLLBACK will undo changes
# Example: cursor.execute("BEGIN")  # operations here  # cursor.execute("COMMIT")

# %% [markdown]
# ## Part 5: Reflection

# %% [markdown]
# ### What did you learn?
#
# Reflect on your capstone project experience:
# - What did you learn about database design?
# - What was the hardest part of this project?
# - What features would you add with more time?

# %% [markdown]
# ## Cleanup

# %%
# Close the database connection
conn.close()
