# %% [markdown]
# # dbApps03a Task: Database Identification Activity
# **Lesson:** 03a — What is a Database?

# %% [markdown]
# ## Part 1: Database Detective
#
# ### Task 1.1: Apps That Use Databases
# List 5 apps on your phone that you think use a database. For each app, write what data it stores.
#
# | App Name | Type of Data It Stores |
# |----------|------------------------|
# | 1. |  |
# | 2. |  |
# | 3. |  |
# | 4. |  |
# | 5. |  |

# %% [markdown]
# ### Task 1.2: CSV vs. Database Problem
# Pick one of the apps from Task 1.1. Explain: What would happen if all its data was stored in a single CSV file instead of a database? What problems would occur?
#
# **App chosen:** _______________
#
# **Your answer:**

# %% [markdown]
# ### Task 1.3: Multiple Users
# For the same app you picked in Task 1.2, who are the different users who might need to access the data at the same time?
#
# **Your answer:**

# %% [markdown]
# ## Part 2: Categorize These Databases
#
# ### Task 2.1: Match Database Type
# For each example below, write whether it would likely be **Relational**, **NoSQL**, or **Cloud**:
#
# a) Student grades at MCCC
#
# b) Instagram posts and comments
#
# c) Amazon product catalog
#
# d) A personal contact list on your phone
#
# e) Netflix viewing history

# %% [markdown]
# ### Task 2.2: Main Difference
# Explain in your own words: What is the main difference between a relational database and a NoSQL database?
#
# **Your answer:**

# %% [markdown]
# ### Task 2.3: Why Schools Use Relational Databases
# Why do you think most schools use relational databases for student records?
#
# **Your answer:**

# %% [markdown]
# ## Part 3: Vocabulary Check
#
# ### Task 3.1–3.4: Match Terms to Definitions
# Match each term on the left with its definition on the right. Write the letter of the definition next to each term.
#
# **Terms:**
# 1. Data
# 2. Information
# 3. Database
# 4. DBMS
# 5. SQL
# 6. Relational Database
# 7. Table
# 8. Row
# 9. Column
# 10. Data Redundancy
#
# **Definitions:**
# A) A collection of related data organized in a structured way
#
# B) The language used to communicate with databases
#
# C) Raw facts and figures (numbers, text, dates, etc.)
#
# D) Software that helps you create, manage, and use databases
#
# E) A database made up of related tables with rows and columns
#
# F) Data that is processed and organized to be meaningful
#
# G) A set of records in a database (horizontal)
#
# H) A grid of rows and columns containing data
#
# I) An attribute or field in a database (vertical)
#
# J) When the same data appears in multiple places
#
# **Your matches:**
# 1. ___ | 2. ___ | 3. ___ | 4. ___ | 5. ___ | 6. ___ | 7. ___ | 8. ___ | 9. ___ | 10. ___
