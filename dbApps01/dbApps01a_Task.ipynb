# %% [markdown]
# # dbApps01a Task: JupyterLab Scavenger Hunt
#
# **Lesson:** 01a — JupyterLab Tour
#
# ---
#
# ## Instructions
#
# Complete each task below. This is your first time working in JupyterLab — take your time and explore!
#
# When finished: Save → Commit → Push to GitHub

# %% [markdown]
# ## Task 1: Hello, World!
#
# Create a code cell below this one and type `print("Hello, Database Applications!")`. Run it with **Shift+Enter**.

# %% [markdown]
# ## Task 2: Create a Markdown Cell with Your Name
#
# Create a **markdown cell** below this one. In it, type your first and last name as a heading using `# Your Name`. Render it with **Shift+Enter**.

# %% [markdown]
# ## Task 3: Math Expression
#
# In a code cell below, type `2 + 2` and run it. What appears below the cell? (Answer in a markdown cell after the code cell.)

# %% [markdown]
# ## Task 4: Multiple Print Statements
#
# In a code cell below, type these three lines and run:
# ```python
# print("Line 1")
# print("Line 2")
# print("Line 3")
# ```
# What order do they print in? Answer in a markdown cell below.

# %% [markdown]
# ## Task 5: Comments in Code
#
# Create a code cell with a comment on the first line, then a print statement on the second:
# ```python
# # This is my comment
# print("Comments are ignored by Python")
# ```

# %% [markdown]
# ## Task 6: Create and Use a Variable
#
# In a code cell below, create a variable called `myName` and assign your name to it (as a string). Then print it.

# %% [markdown]
# ## Task 7: Create a Numeric Variable
#
# In a code cell below, create a variable called `myAge` and assign your age to it (as a number, no quotes). Then print it.

# %% [markdown]
# ## Task 8: Check Variable Types
#
# In a code cell below, use `type()` to check the types of `myName` and `myAge`. Print both results.

# %% [markdown]
# ## Task 9: Reflection
#
# Create a markdown cell below and write a short paragraph (2–3 sentences) about what you've learned so far in this scavenger hunt.

# %% [markdown]
# ## Task 10: Intentional Error
#
# In a code cell below, try running something that will cause an error on purpose. For example, type `print("hello` (without the closing quote). Don't fix it — just observe the error message and describe what you see in a markdown cell below.
