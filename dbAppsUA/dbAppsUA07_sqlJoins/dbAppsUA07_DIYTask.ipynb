# %% [markdown]
# # dbAppsUA07 DIY Завдання: SQL JOIN
#
# Використовуйте базу даних IMDb.

# %%
# Налаштування
import pandas as pd
import sqlite3

conn = sqlite3.connect('imdb_class.db')
print('Підключено!')

# %% [markdown]
# ## Частина 1: INNER JOIN

# %% [markdown]
# ### Завдання 1.1
#
# Знайдіть 10 фільмів з найвищим рейтингом (мінімум 5000 голосів). Покажіть назву, рік, рейтинг, кількість голосів.

# %%
# Завдання 1.1

# %% [markdown]
# ### Завдання 1.2
#
# Знайдіть всіх акторів фільму 'Interstellar'. Покажіть назву фільму, ім'я актора, роль.

# %%
# Завдання 1.2

# %% [markdown]
# ## Частина 2: LEFT JOIN

# %% [markdown]
# ### Завдання 2.1
#
# Знайдіть серіали (titleType = 'tvSeries') без рейтингів. Покажіть назву та рік. Скільки серіалів без рейтингу?

# %%
# Завдання 2.1

# %% [markdown]
# ## Частина 3: Складні запити

# %% [markdown]
# ### Завдання 3.1
#
# Порахуйте скільки фільмів у кожного режисера (category = 'director'). Покажіть топ 10 найпродуктивніших режисерів.

# %%
# Завдання 3.1

# %% [markdown]
# ### Завдання 3.2
#
# Знайдіть акторів які знімались мінімум у 5 фільмах з середнім рейтингом вищим за 7.5. Покажіть ім'я, кількість фільмів, середній рейтинг.

# %%
# Завдання 3.2

# %% [markdown]
# ### Завдання 3.3
#
# Напишіть свій складний запит що використовує мінімум 2 JOIN + GROUP BY + HAVING. Поясніть що шукає ваш запит.

# %%
# Завдання 3.3

# %% [markdown]
# **Опис запиту:**

# %% [markdown]
# ## Частина 4: Словник
#
# **INNER JOIN:** ___
#
# **LEFT JOIN:** ___
#
# **ON clause:** ___
#
# **Table alias:** ___
#
# **NULL:** ___

# %%
conn.close()
print("З'єднання закрито!")
