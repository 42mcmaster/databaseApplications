# %% [markdown]
# # dbAppsUA07 Завдання: SQL JOIN
#
# **Урок:** 07 — INNER JOIN, LEFT JOIN, багатотабличні JOIN

# %%
# Налаштування
import pandas as pd
import sqlite3

conn = sqlite3.connect('imdb_class.db')
print('Підключено до IMDb!')

# %% [markdown]
# ## Завдання 1: Базовий INNER JOIN
#
# З'єднайте `title_basics` та `title_ratings` на `tconst`. Покажіть primaryTitle, startYear, averageRating перших 10 фільмів.

# %%
# Завдання 1

# %% [markdown]
# ## Завдання 2: INNER JOIN з фільтром
#
# Знайдіть фільми з рейтингом вищим за 8.0 та мінімум 10000 голосів. Покажіть назву, рік, рейтинг. Топ 10.

# %%
# Завдання 2

# %% [markdown]
# ## Завдання 3: LEFT JOIN
#
# Використайте LEFT JOIN щоб знайти фільми БЕЗ рейтингів (де averageRating IS NULL). Покажіть назву та рік.

# %%
# Завдання 3

# %% [markdown]
# ## Завдання 4: Три таблиці JOIN
#
# З'єднайте title_basics → title_principals → name_basics щоб знайти акторів фільмів 2020 року. Покажіть назву фільму, ім'я актора, роль.

# %%
# Завдання 4

# %% [markdown]
# ## Завдання 5: JOIN + GROUP BY
#
# Порахуйте скільки фільмів у кожного актора. Покажіть ім'я та кількість. Топ 10 за кількістю фільмів.

# %%
# Завдання 5

# %% [markdown]
# ## Завдання 6: Складний запит
#
# Знайдіть акторів з середнім рейтингом фільмів вищим за 7.0 та мінімум 3 фільми. Покажіть ім'я, кількість фільмів, середній рейтинг.

# %%
# Завдання 6

# %%
conn.close()
print("З'єднання закрито!")
