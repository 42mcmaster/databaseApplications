# %% [markdown]
# # dbAppsUA06 DIY Завдання: Проектування баз даних
#
# Використовуйте базу даних IMDb.

# %%
# Налаштування
import pandas as pd
import sqlite3

conn = sqlite3.connect('imdb_class_2010plus.db')
print('Підключено!')

# %% [markdown]
# ## Частина 1: Первинні ключі

# %% [markdown]
# ### Завдання 1.1
#
# Доведіть що `nconst` у `name_basics` є первинним ключем (порахуйте загальну кількість рядків та DISTINCT nconst).

# %%
# Завдання 1.1

# %% [markdown]
# ### Завдання 1.2
#
# Знайдіть 5 найпопулярніших імен (primaryName) що повторюються в `name_basics`. Чому ім'я не може бути ключем?

# %%
# Завдання 1.2

# %% [markdown]
# ## Частина 2: Зовнішні ключі та JOIN

# %% [markdown]
# ### Завдання 2.1
#
# Використайте JOIN через зовнішні ключі щоб знайти режисерів (category = 'director') фільмів з рейтингом вищим за 8.0. З'єднайте 4 таблиці: title_basics, title_principals, name_basics, title_ratings.

# %%
# Завдання 2.1

# %% [markdown]
# ## Частина 3: Надлишковість

# %% [markdown]
# ### Завдання 3.1
#
# Оберіть конкретний фільм. Порахуйте скільки рядків у title_principals посилаються на цей фільм. Поясніть: скільки разів інформація про фільм була б дубльована у поганому дизайні?

# %%
# Завдання 3.1

# %% [markdown]
# **Пояснення:**

# %% [markdown]
# ## Частина 4: Концепції
#
# ### Завдання 4.1
#
# Дайте визначення:
#
# **Первинний ключ (Primary Key):** ___
#
# **Зовнішній ключ (Foreign Key):** ___
#
# **Надлишковість (Redundancy):** ___
#
# **Нормалізація (Normalization):** ___

# %%
conn.close()
print("З'єднання закрито!")
