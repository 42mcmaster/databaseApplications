# %% [markdown]
# # dbAppsUA06 Завдання: Проектування баз даних
#
# **Урок:** 06 — Первинні ключі, зовнішні ключі, нормалізація

# %%
# Налаштування
import pandas as pd
import sqlite3

conn = sqlite3.connect('imdb_class_2010plus.db')
print('Підключено до IMDb!')

# %% [markdown]
# ## Завдання 1: Перевірка первинного ключа
#
# Доведіть що `nconst` у таблиці `name_basics` є унікальним. Порахуйте загальну кількість рядків та кількість DISTINCT nconst.

# %%
# Завдання 1

# %% [markdown]
# ## Завдання 2: Чому ім'я не ключ?
#
# Знайдіть імена (primaryName) в `name_basics` що повторюються. Покажіть топ 10 за кількістю повторів.

# %%
# Завдання 2

# %% [markdown]
# ## Завдання 3: JOIN через зовнішні ключі
#
# З'єднайте `title_basics` та `title_principals` та `name_basics` щоб знайти акторів фільму 'Inception'. Покажіть назву фільму, ім'я актора, та роль.

# %%
# Завдання 3

# %% [markdown]
# ## Завдання 4: Надлишковість
#
# Порахуйте скільки записів у `title_principals` та скільки унікальних фільмів (DISTINCT tconst). Обчисліть різницю — це кількість усунутих дублікатів.

# %%
# Завдання 4

# %% [markdown]
# ## Завдання 5: Рефлексія
#
# Напишіть 2-3 речення: Чому зберігання даних в окремих таблицях краще ніж в одній великій таблиці?

# %%
conn.close()
print("З'єднання закрито!")
