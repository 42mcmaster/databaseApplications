# %% [markdown]
# # dbAppsUA02 Завдання: Робота з DataFrame
#
# **Урок:** 02 — DataFrames у pandas
#
# Виконайте кожне завдання використовуючи набір даних Titanic.

# %%
# Налаштування
import pandas as pd
titanic = pd.read_csv("Titanic Dataset.csv")
print("Дані завантажено:", titanic.shape)

# %% [markdown]
# ## Завдання 1: Вибір стовпців
#
# Виберіть стовпці `name`, `age` та `fare`. Покажіть перші 10 рядків.

# %%
# Завдання 1

# %% [markdown]
# ## Завдання 2: Фільтрація
#
# Знайдіть всіх пасажирів першого класу (`pclass == 1`). Скільки їх?

# %%
# Завдання 2

# %% [markdown]
# ## Завдання 3: Комбінована фільтрація
#
# Знайдіть жінок (`sex == 'female'`) які вижили (`survived == 1`). Покажіть їх імена та вік.

# %%
# Завдання 3

# %% [markdown]
# ## Завдання 4: Сортування
#
# Відсортуйте пасажирів за ціною квитка (`fare`) від найвищої до найнижчої. Покажіть топ 5.

# %%
# Завдання 4

# %% [markdown]
# ## Завдання 5: Статистика
#
# Обчисліть середній вік пасажирів кожного класу (pclass 1, 2, 3) окремо.

# %%
# Завдання 5

# %% [markdown]
# ## Завдання 6: Value Counts
#
# Використайте `.value_counts()` на стовпці `embarked`. Який порт мав найбільше пасажирів?

# %%
# Завдання 6
