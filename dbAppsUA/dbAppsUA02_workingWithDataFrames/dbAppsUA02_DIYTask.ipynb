# %% [markdown]
# # dbAppsUA02 DIY Завдання: Робота з DataFrame
#
# Використовуйте набір даних Titanic для всіх завдань.

# %%
# Налаштування
import pandas as pd
titanic = pd.read_csv("Titanic Dataset.csv")
print("Завантажено:", titanic.shape)

# %% [markdown]
# ## Частина 1: Вибір та фільтрація

# %% [markdown]
# ### Завдання 1.1
#
# Виберіть стовпці `name`, `sex`, `age`, `fare`. Покажіть перші 10 рядків.

# %%
# Завдання 1.1

# %% [markdown]
# ### Завдання 1.2
#
# Знайдіть всіх дітей (вік <= 12) які вижили. Скільки їх? Покажіть їх імена та вік.

# %%
# Завдання 1.2

# %% [markdown]
# ### Завдання 1.3
#
# Знайдіть чоловіків третього класу які НЕ вижили. Скільки їх?

# %%
# Завдання 1.3

# %% [markdown]
# ## Частина 2: Сортування та статистика

# %% [markdown]
# ### Завдання 2.1
#
# Знайдіть 10 найдорожчих квитків. Покажіть name, fare, pclass.

# %%
# Завдання 2.1

# %% [markdown]
# ### Завдання 2.2
#
# Обчисліть середню ціну квитка для кожного класу (1, 2, 3) окремо. Яка різниця між першим і третім?

# %%
# Завдання 2.2

# %% [markdown]
# ### Завдання 2.3
#
# Використайте `.value_counts()` на стовпці `survived`. Який відсоток пасажирів вижив?

# %%
# Завдання 2.3

# %% [markdown]
# ## Частина 3: Аналіз
#
# ### Завдання 3.1
#
# Порівняйте виживання за статтю: який відсоток жінок вижив? Який відсоток чоловіків? Напишіть висновок у markdown.

# %%
# Завдання 3.1

# %% [markdown]
# **Висновок:**
