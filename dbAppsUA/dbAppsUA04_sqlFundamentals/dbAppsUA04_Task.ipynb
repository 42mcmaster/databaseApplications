# %% [markdown]
# # dbAppsUA04 Завдання: SQL Запити
#
# **Урок:** 04 — SELECT, WHERE, ORDER BY
#
# Виконайте кожне завдання використовуючи базу даних Titanic.

# %%
# Налаштування
import pandas as pd
import sqlite3

conn = sqlite3.connect("titanic.db")
print("Підключено!")

# %% [markdown]
# ## Завдання 1: Базовий SELECT
#
# Напишіть запит що показує `name`, `age` та `fare` перших 15 пасажирів.

# %%
# Завдання 1
query = ""
result = pd.read_sql(query, conn)
result

# %% [markdown]
# ## Завдання 2: WHERE з порівнянням
#
# Знайдіть всіх пасажирів старших за 60 років. Покажіть їх ім'я та вік.

# %%
# Завдання 2
query = ""
result = pd.read_sql(query, conn)
result

# %% [markdown]
# ## Завдання 3: AND
#
# Знайдіть жінок першого класу. Покажіть name, sex, pclass.

# %%
# Завдання 3
query = ""
result = pd.read_sql(query, conn)
result

# %% [markdown]
# ## Завдання 4: LIKE
#
# Знайдіть пасажирів чиє ім'я починається з 'A'. Покажіть name.

# %%
# Завдання 4
query = ""
result = pd.read_sql(query, conn)
result

# %% [markdown]
# ## Завдання 5: BETWEEN та IN
#
# Знайдіть пасажирів віком від 25 до 35 які сіли в порту 'S' або 'C'. Покажіть name, age, embarked.

# %%
# Завдання 5
query = ""
result = pd.read_sql(query, conn)
result

# %% [markdown]
# ## Завдання 6: ORDER BY
#
# Знайдіть 10 найдорожчих квитків. Покажіть name, fare, pclass відсортовані за fare DESC.

# %%
# Завдання 6
query = ""
result = pd.read_sql(query, conn)
result

# %% [markdown]
# ## Завдання 7: Комбінований запит
#
# Знайдіть 5 найстарших чоловіків які вижили. Покажіть name, age, survived.

# %%
# Завдання 7
query = ""
result = pd.read_sql(query, conn)
result

# %%
conn.close()
print("З'єднання закрито!")
