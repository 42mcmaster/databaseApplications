# %% [markdown]
# # dbAppsUA04 DIY Завдання: SQL Запити
#
# Використовуйте базу даних Titanic.

# %%
# Налаштування
import pandas as pd
import sqlite3
import os

if not os.path.exists('titanic.db'):
    df = pd.read_csv('Titanic Dataset.csv')
    conn = sqlite3.connect('titanic.db')
    df.to_sql('passengers', conn, index=False, if_exists='replace')
else:
    conn = sqlite3.connect('titanic.db')
print("Підключено!")

# %% [markdown]
# ## Частина 1: Цільові запити

# %% [markdown]
# ### Завдання 1.1
#
# Знайдіть 10 найстарших пасажирів. Покажіть name та age, відсортуйте за age DESC.

# %%
# Завдання 1.1
query = ""
result = pd.read_sql(query, conn)
result

# %% [markdown]
# ### Завдання 1.2
#
# Знайдіть всіх дітей (age <= 12) які вижили. Покажіть name, age, survived. Сортуйте за age.

# %%
# Завдання 1.2
query = ""
result = pd.read_sql(query, conn)
result

# %% [markdown]
# ### Завдання 1.3
#
# Знайдіть пасажирів чиє ім'я містить 'Dr.'. Покажіть name, survived, pclass.

# %%
# Завдання 1.3
query = ""
result = pd.read_sql(query, conn)
result

# %% [markdown]
# ### Завдання 1.4
#
# Знайдіть пасажирів віком 18-25 з першого класу. Покажіть name, age, pclass, fare. Сортуйте за fare DESC.

# %%
# Завдання 1.4
query = ""
result = pd.read_sql(query, conn)
result

# %% [markdown]
# ## Частина 2: Аналіз

# %% [markdown]
# ### Завдання 2.1
#
# Скільки жінок вижило? Скільки чоловіків? Напишіть два запити та порівняйте.

# %%
# Завдання 2.1: Жінки які вижили
query = ""
result = pd.read_sql(query, conn)
print("Жінок які вижили:", len(result))

# %%
# Завдання 2.1: Чоловіки які вижили
query = ""
result = pd.read_sql(query, conn)
print("Чоловіків які вижили:", len(result))

# %% [markdown]
# **Аналіз:** (Напишіть що ви помітили)

# %% [markdown]
# ### Завдання 2.2
#
# Напишіть складний запит що комбінує: конкретні стовпці, WHERE з AND, ORDER BY DESC та LIMIT. Опишіть що шукає ваш запит.

# %%
# Завдання 2.2
query = ""
result = pd.read_sql(query, conn)
result

# %% [markdown]
# **Опис запиту:**

# %% [markdown]
# ## Частина 3: Словник
#
# ### Завдання 3.1
#
# Дайте визначення своїми словами:
#
# **WHERE:** ___
#
# **LIKE:** ___
#
# **BETWEEN:** ___
#
# **IN:** ___
#
# **ORDER BY:** ___

# %%
conn.close()
print("З'єднання закрито!")
