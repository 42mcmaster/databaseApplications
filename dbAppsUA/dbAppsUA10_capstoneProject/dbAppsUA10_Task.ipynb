# %% [markdown]
# # dbAppsUA10 Завдання: Планування проекту
#
# **Урок:** 10 — Підсумковий проект
#
# Це завдання допоможе вам спланувати підсумковий проект.

# %% [markdown]
# ## Завдання 1: Вибір теми
#
# Оберіть тему для бази даних. Опишіть одним абзацом: що зберігає, для кого, яку проблему вирішує.
#
# **Моя тема:**

# %% [markdown]
# ## Завдання 2: Сутності
#
# Перечисліть мінімум 2 таблиці (сутності). Для кожної напишіть 3-5 стовпців.
#
# | Таблиця | Стовпці |
# |---------|--------|
# | | |
# | | |

# %% [markdown]
# ## Завдання 3: Зв'язки
#
# Опишіть зв'язки між таблицями. Які зовнішні ключі потрібні?
#
# **Зв'язки:**

# %% [markdown]
# ## Завдання 4: ER Діаграма
#
# Намалюйте просту ER діаграму (можна ASCII або на папері). Покажіть таблиці, стовпці та зв'язки.

# %% [markdown]
# ## Завдання 5: Приклади запитів
#
# Напишіть 3 запитання які ви хочете відповісти за допомогою SQL запитів до вашої бази даних.
#
# 1.
# 2.
# 3.

# %% [markdown]
# ## Завдання 6: CREATE TABLE
#
# Напишіть CREATE TABLE SQL для кожної вашої таблиці. Включіть PKs, FKs та обмеження.

# %%
# Завдання 6: Ваші CREATE TABLE тут
