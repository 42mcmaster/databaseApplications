# %% [markdown]
# # dbAppsUA10: Підсумковий проект (Capstone Project)
#
# **Курс:** Застосування баз даних
#
# **Тема:** *(напишіть свою тему тут)*

# %% [markdown]
# ## Налаштування

# %%
import pandas as pd
import sqlite3

# Підключаємося до файлу бази даних
conn = sqlite3.connect('my_project.db')
cursor = conn.cursor()

# %% [markdown]
# ## Частина 1: Проектування (Design)
#
# ### Моя тема
#
# Опишіть ідею вашої бази даних:
# - Яку проблему вирішує?
# - Які сутності (entities) та зв'язки (relationships) важливі?

# %% [markdown]
# ### ER Діаграма
#
# Намалюйте діаграму сутність-зв'язок (Entity-Relationship) у ASCII форматі.
# Покажіть таблиці та їх зв'язки.

# %% [markdown]
# ### Словник даних (Data Dictionary)
#
# | Таблиця | Стовпець | Тип | Обмеження | Нотатки |
# |---------|----------|-----|-----------|--------|
# | | | | | |

# %% [markdown]
# ## Частина 2: Створення (Build)
#
# ### CREATE TABLE

# %%
# Створіть ваші таблиці тут
# Пам'ятайте: PRIMARY KEY, FOREIGN KEY, NOT NULL, UNIQUE, CHECK, DEFAULT

# %% [markdown]
# ### INSERT — Вставити дані

# %%
# Вставте ваші записи тут (мінімум 15 записів у кожній основній таблиці)
# Використовуйте окремі INSERT INTO для кожного запису

# %% [markdown]
# ### Перевірка таблиць

# %%
# Запустіть SELECT * для кожної таблиці щоб перевірити дані

# %% [markdown]
# ## Частина 3: Запити (Queries)
#
# Напишіть мінімум 8 запитів що демонструють різні навички SQL.

# %% [markdown]
# ### Запит 1: SELECT з WHERE

# %%
# Простий SELECT запит з WHERE

# %% [markdown]
# ### Запит 2: SELECT з кількома умовами

# %%
# Запит з AND, OR або іншими умовами

# %% [markdown]
# ### Запит 3: ORDER BY та LIMIT

# %%
# Сортування та обмеження результатів

# %% [markdown]
# ### Запит 4: Агрегатна функція

# %%
# COUNT, SUM, AVG, MIN або MAX

# %% [markdown]
# ### Запит 5: GROUP BY

# %%
# GROUP BY з агрегатною функцією

# %% [markdown]
# ### Запит 6: GROUP BY з HAVING

# %%
# GROUP BY з HAVING для фільтрації груп

# %% [markdown]
# ### Запит 7: INNER JOIN

# %%
# INNER JOIN між двома таблицями

# %% [markdown]
# ### Запит 8: LEFT JOIN або складний запит

# %%
# LEFT JOIN або складний запит що демонструє вашу навичку

# %% [markdown]
# ## Частина 4: Безпека (Security)

# %% [markdown]
# ### Параметризований запит

# %%
# Покажіть мінімум один параметризований запит з ?

# %% [markdown]
# ### Транзакція

# %%
# Покажіть BEGIN, операції та COMMIT

# %% [markdown]
# ## Частина 5: Рефлексія
#
# ### Що ви дізнались?
#
# - Що ви дізнались про проектування баз даних?
# - Що було найскладнішим?
# - Які функції ви б додали маючи більше часу?

# %% [markdown]
# ## Закриття

# %%
# Закриваємо з'єднання з базою даних
conn.close()
