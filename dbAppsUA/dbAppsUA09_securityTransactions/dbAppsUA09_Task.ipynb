# %% [markdown]
# # dbAppsUA09 Завдання: Безпека та транзакції
#
# **Урок:** 09 — SQL ін'єкція, параметризовані запити, транзакції

# %%
# Налаштування
import pandas as pd
import sqlite3

conn = sqlite3.connect(":memory:")
print("Підключено!")

# %% [markdown]
# ## Завдання 1: Створення тестових даних
#
# Створіть таблицю `accounts` з accountId (PK), name (TEXT), balance (REAL). Вставте 3 рахунки.

# %%
# Завдання 1

# %% [markdown]
# ## Завдання 2: Вразливий запит
#
# Напишіть запит з конкатенацією рядків (f-string). Потім у коментарі поясніть чому це небезпечно.

# %%
# Завдання 2: ВРАЗЛИВИЙ запит (тільки для демонстрації!)

# %% [markdown]
# ## Завдання 3: Безпечний запит
#
# Перепишіть запит з Завдання 2 використовуючи параметризований підхід з `?`.

# %%
# Завдання 3: БЕЗПЕЧНИЙ параметризований запит

# %% [markdown]
# ## Завдання 4: Транзакція COMMIT
#
# Напишіть транзакцію що переказує гроші між двома рахунками. Використайте BEGIN та COMMIT. Перевірте баланси.

# %%
# Завдання 4

# %% [markdown]
# ## Завдання 5: Транзакція ROLLBACK
#
# Напишіть транзакцію що намагається зняти більше грошей ніж є на рахунку. Використайте ROLLBACK. Перевірте що баланс відновлено.

# %%
# Завдання 5

# %% [markdown]
# ## Завдання 6: ACID
#
# Поясніть кожну властивість ACID одним реченням:
#
# - **A (Atomicity):**
# - **C (Consistency):**
# - **I (Isolation):**
# - **D (Durability):**
