# %% [markdown]
# # dbAppsUA09 DIY Завдання: Безпека та транзакції
#
# Створіть систему банківських рахунків та продемонструйте безпеку і транзакції.

# %%
# Налаштування
import pandas as pd
import sqlite3

conn = sqlite3.connect(":memory:")
print("Підключено!")

# %% [markdown]
# ## Частина 1: Налаштування даних
#
# ### Завдання 1.1
#
# Створіть таблицю `customers` (customerId PK, name TEXT, email TEXT UNIQUE) та таблицю `accounts` (accountId PK, customerId FK, accountType TEXT, balance REAL). Вставте мінімум 3 клієнти та 4 рахунки.

# %%
# Завдання 1.1: Створення таблиць та даних

# %% [markdown]
# ## Частина 2: SQL Ін'єкція
#
# ### Завдання 2.1
#
# Покажіть вразливий запит (конкатенація) та безпечний запит (параметризований) для пошуку клієнта за ім'ям. Поясніть у коментарях різницю.

# %%
# Завдання 2.1: Вразливий vs безпечний

# %% [markdown]
# ## Частина 3: Транзакції
#
# ### Завдання 3.1
#
# Напишіть транзакцію з COMMIT: переказ грошей між двома рахунками. Покажіть баланси до та після.

# %%
# Завдання 3.1: Транзакція з COMMIT

# %% [markdown]
# ### Завдання 3.2
#
# Напишіть транзакцію з ROLLBACK: спроба зняти більше ніж є на рахунку. Покажіть що баланс відновлено.

# %%
# Завдання 3.2: Транзакція з ROLLBACK

# %% [markdown]
# ## Частина 4: Концепції
#
# ### Завдання 4.1
#
# Поясніть ACID своїми словами:
#
# **Atomicity:** ___
#
# **Consistency:** ___
#
# **Isolation:** ___
#
# **Durability:** ___
#
# ### Завдання 4.2
#
# Наведіть реальний приклад (не банківський переказ) де транзакція необхідна:
#
# **Приклад:** ___
#
# **Чому потрібна транзакція:** ___

# %%
conn.close()
print("З'єднання закрито!")
