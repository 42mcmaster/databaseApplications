# %% [markdown]
# # dbAppsUA05 Завдання: Агрегації та GROUP BY
#
# **Урок:** 05 — COUNT, SUM, AVG, GROUP BY, HAVING
#
# Використовуйте базу даних NBA.

# %%
# Налаштування
import pandas as pd
import sqlite3

conn = sqlite3.connect('nba_5seasons.db')
print('Підключено!')

# %% [markdown]
# ## Завдання 1: COUNT
#
# Порахуйте загальну кількість записів у таблиці `team_game_stats`.

# %%
# Завдання 1

# %% [markdown]
# ## Завдання 2: AVG та ROUND
#
# Обчисліть середню кількість очків (`pts`) за гру з `team_game_stats`, округлену до 1 знаку.

# %%
# Завдання 2

# %% [markdown]
# ## Завдання 3: MIN та MAX
#
# Знайдіть мінімальну та максимальну кількість очків за сезон з `player_season_stats`.

# %%
# Завдання 3

# %% [markdown]
# ## Завдання 4: GROUP BY
#
# Згрупуйте `team_game_stats` за `team_id` і покажіть кількість ігор та середні очки за гру. Топ 5 за середніми очками.

# %%
# Завдання 4

# %% [markdown]
# ## Завдання 5: HAVING
#
# Знайдіть гравців (з `player_season_stats`) які набирали в середньому більше 15 очків за сезон. Покажіть player_id, кількість сезонів, середні очки.

# %%
# Завдання 5

# %% [markdown]
# ## Завдання 6: WHERE + GROUP BY + HAVING
#
# Знайдіть команди у сезоні 2023 з більш ніж 30 перемогами. Покажіть team_id та кількість перемог.

# %%
# Завдання 6

# %% [markdown]
# ## Завдання 7: Експорт у Excel
#
# Запустіть один з ваших запитів та експортуйте результат у файл `my_analysis.xlsx`.

# %%
# Завдання 7

# %%
conn.close()
print("З'єднання закрито!")
