# %% [markdown]
# # dbAppsUA05 DIY Завдання: Агрегації та GROUP BY
#
# Використовуйте базу даних NBA.

# %%
# Налаштування
import pandas as pd
import sqlite3

conn = sqlite3.connect('nba_5seasons.db')
print('Підключено!')

# %% [markdown]
# ## Частина 1: Агрегатні функції

# %% [markdown]
# ### Завдання 1.1
#
# Обчисліть загальну кількість ігор, середні очки за гру та максимальні очки з `team_game_stats`.

# %%
# Завдання 1.1

# %% [markdown]
# ### Завдання 1.2
#
# Знайдіть гравця з найбільшою кількістю очків за один сезон з `player_season_stats`.

# %%
# Завдання 1.2

# %% [markdown]
# ## Частина 2: GROUP BY та HAVING

# %% [markdown]
# ### Завдання 2.1
#
# Згрупуйте `team_game_stats` за командою та сезоном. Покажіть кількість ігор та середні очки. Сортуйте за середніми очками DESC. Топ 10.

# %%
# Завдання 2.1

# %% [markdown]
# ### Завдання 2.2
#
# Знайдіть команди з більш ніж 200 перемогами за всі сезони. Покажіть team_id та кількість перемог.

# %%
# Завдання 2.2

# %% [markdown]
# ### Завдання 2.3
#
# Знайдіть гравців які набирали в середньому більше 25 очків за сезон і грали мінімум 2 сезони.

# %%
# Завдання 2.3

# %% [markdown]
# ## Частина 3: Експорт
#
# ### Завдання 3.1
#
# Створіть запит що знаходить топ-5 команд за середніми очками у сезоні 2023. Експортуйте результат у `top_teams_2023.xlsx`.

# %%
# Завдання 3.1

# %% [markdown]
# ## Частина 4: Словник
#
# ### Завдання 4.1
#
# Поясніть різницю між WHERE та HAVING:
#
# **WHERE:** ___
#
# **HAVING:** ___
#
# Коли використовувати кожен? ___

# %%
conn.close()
print("З'єднання закрито!")
