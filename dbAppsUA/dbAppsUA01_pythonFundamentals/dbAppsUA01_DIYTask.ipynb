# %% [markdown]
# # dbAppsUA01 DIY Завдання: Основи Python та JupyterLab
#
# Виконайте всі завдання нижче. Використовуйте зошит-довідник та навчальний посібник.
#
# Коли закінчите: Збережіть → Commit → Push на GitHub.

# %% [markdown]
# ## Частина 1: Змінні та типи даних

# %% [markdown]
# ### Завдання 1.1
#
# Створіть 5 змінних з правильними назвами **camelCase**:
# - Ваше ім'я (рядок)
# - Ваше прізвище (рядок)
# - Ваш клас (ціле число)
# - Ваш середній бал (число з комою)
# - Чи є у вас робота (булевий)
#
# Надрукуйте всі 5 з описовими мітками.

# %%
# Завдання 1.1: Створіть 5 змінних і надрукуйте їх

# %% [markdown]
# ### Завдання 1.2
#
# Використайте `type()` щоб перевірити тип кожної змінної з 1.1.

# %%
# Завдання 1.2: Перевірте типи даних

# %% [markdown]
# ## Частина 2: Математика та обчислення

# %% [markdown]
# ### Завдання 2.1
#
# Магазин продає зошити по $4.25 та ручки по $1.75. Студент купує 3 зошити та 5 ручок. Обчисліть:
# - Вартість зошитів
# - Вартість ручок
# - Загальну вартість
#
# Збережіть кожне у змінну з camelCase та надрукуйте з мітками.

# %%
# Завдання 2.1: Обчисліть вартість покупки

# %% [markdown]
# ### Завдання 2.2
#
# Студент отримав оцінки за 4 тести: 92, 85, 78, 96. Обчисліть суму та середнє. Надрукуйте результат з f-string.

# %%
# Завдання 2.2: Обчисліть середній бал

# %% [markdown]
# ## Частина 3: pandas та Titanic

# %% [markdown]
# ### Завдання 3.1
#
# Імпортуйте pandas та завантажте `Titanic Dataset.csv` у DataFrame `titanic`.

# %%
# Завдання 3.1

# %% [markdown]
# ### Завдання 3.2
#
# Покажіть перші 8 рядків набору даних.

# %%
# Завдання 3.2

# %% [markdown]
# ### Завдання 3.3
#
# Запустіть `.info()` та `.describe()` на наборі даних.

# %%
# Завдання 3.3

# %% [markdown]
# ### Завдання 3.4: Відповіді
#
# Використовуючи результати `.info()` та `.describe()`:
#
# 1. Скільки пасажирів у наборі? ___
# 2. Скільки стовпців? ___
# 3. Який середній вік пасажирів? ___
# 4. Яка максимальна ціна квитка? ___

# %% [markdown]
# ## Частина 4: Словник
#
# ### Завдання 4.1
#
# Дайте визначення своїми словами:
#
# 1. **Змінна (Variable):** ___
# 2. **Тип даних (Data Type):** ___
# 3. **Коментар (Comment):** ___
# 4. **camelCase:** ___
# 5. **DataFrame:** ___
# 6. **CSV:** ___

# %% [markdown]
# ## Контрольний список
#
# - [ ] Всі комірки коду запускаються без помилок
# - [ ] Всі змінні використовують camelCase
# - [ ] Код містить коментарі
# - [ ] Відповіді на запитання заповнені
# - [ ] Зошит збережено та завантажено на GitHub
