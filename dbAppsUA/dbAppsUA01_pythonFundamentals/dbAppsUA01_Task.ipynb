# %% [markdown]
# # dbAppsUA01 Завдання: Основи Python
#
# **Урок:** 01 — Python та JupyterLab
#
# Виконайте кожне завдання нижче. Коли закінчите: Збережіть → Commit → Push на GitHub

# %% [markdown]
# ## Завдання 1: Привіт, світ!
#
# Створіть код нижче з `print("Привіт, Застосування баз даних!")`. Запустіть з **Shift+Enter**.

# %%
# Завдання 1: Ваш код тут

# %% [markdown]
# ## Завдання 2: Змінні
#
# Створіть змінну `myName` з вашим ім'ям (рядок) та змінну `myAge` з вашим віком (число). Надрукуйте обидві.

# %%
# Завдання 2: Ваш код тут

# %% [markdown]
# ## Завдання 3: Типи даних
#
# Використайте `type()` щоб перевірити типи `myName` та `myAge`. Надрукуйте результати.

# %%
# Завдання 3: Ваш код тут

# %% [markdown]
# ## Завдання 4: Математика
#
# Обчисліть загальну вартість 5 квитків по $15.50 кожен. Збережіть у змінну `totalCost` та надрукуйте результат за допомогою f-string.

# %%
# Завдання 4: Ваш код тут

# %% [markdown]
# ## Завдання 5: Завантаження даних
#
# Імпортуйте pandas, завантажте `Titanic Dataset.csv` у DataFrame `titanic`. Виведіть `.shape` та `.head()`.

# %%
# Завдання 5: Ваш код тут

# %% [markdown]
# ## Завдання 6: Дослідження даних
#
# Використайте `.describe()` та `.columns.tolist()` на DataFrame titanic. Скільки числових стовпців?

# %%
# Завдання 6: Ваш код тут

# %% [markdown]
# ## Рефлексія
#
# Напишіть 2-3 речення про те, що ви дізнались у цьому завданні.
