# %% [markdown]
# # dbAppsUA03 Завдання: Вступ до баз даних
#
# **Урок:** 03 — Бази даних та SQLite

# %% [markdown]
# ## Частина 1: Розуміння баз даних
#
# ### Завдання 1.1: Додатки з базами даних
#
# Назвіть 3 додатки на вашому телефоні які використовують базу даних. Для кожного напишіть які дані вони зберігають.
#
# | Додаток | Які дані зберігає |
# |---------|-------------------|
# | 1. | |
# | 2. | |
# | 3. | |

# %% [markdown]
# ### Завдання 1.2: CSV проти бази даних
#
# Виберіть один додаток з Завдання 1.1. Поясніть: що станеться якщо всі його дані зберігались в одному CSV файлі?
#
# **Ваша відповідь:**

# %% [markdown]
# ## Частина 2: Практика з SQLite
#
# ### Завдання 2.1: Створення бази даних
#
# Імпортуйте pandas та sqlite3. Завантажте Titanic CSV та збережіть його як таблицю `passengers` у базі `titanic.db`.

# %%
# Завдання 2.1: Ваш код тут

# %% [markdown]
# ### Завдання 2.2: Перший SQL запит
#
# Напишіть SQL запит щоб вибрати `name`, `age`, `survived` з перших 10 пасажирів.

# %%
# Завдання 2.2: Ваш код тут

# %% [markdown]
# ### Завдання 2.3: Структура бази даних
#
# Використайте `PRAGMA table_info(passengers)` щоб побачити стовпці таблиці. Скільки стовпців?

# %%
# Завдання 2.3: Ваш код тут

# %% [markdown]
# ### Завдання 2.4: Закриття
#
# Закрийте з'єднання з базою даних.

# %%
# Завдання 2.4
conn.close()
print("З'єднання закрито!")
