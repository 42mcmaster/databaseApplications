# %% [markdown]
# # dbAppsUA03 DIY Завдання: Вступ до баз даних
#
# Практикуйте створення та запити бази даних SQLite.

# %% [markdown]
# ## Частина 1: Створення бази даних

# %% [markdown]
# ### Завдання 1.1
#
# Імпортуйте pandas та sqlite3. Завантажте `Titanic Dataset.csv`. Створіть базу `titanic_diy.db` та збережіть дані як таблицю `passengers`.

# %%
# Завдання 1.1

# %% [markdown]
# ### Завдання 1.2
#
# Перевірте структуру: виведіть список таблиць та інформацію про стовпці (PRAGMA).

# %%
# Завдання 1.2

# %% [markdown]
# ## Частина 2: SQL Запити

# %% [markdown]
# ### Завдання 2.1
#
# Напишіть SQL запит що показує name, age, survived перших 15 пасажирів.

# %%
# Завдання 2.1

# %% [markdown]
# ### Завдання 2.2
#
# Напишіть SQL запит що показує тільки жінок. Скільки результатів?

# %%
# Завдання 2.2

# %% [markdown]
# ### Завдання 2.3
#
# Напишіть SQL запит що показує пасажирів першого класу старших за 50.

# %%
# Завдання 2.3

# %% [markdown]
# ## Частина 3: Порівняння
#
# ### Завдання 3.1
#
# Виконайте один і той же фільтр у pandas та SQL. Порівняйте результати.
#
# **pandas:** `titanic[titanic["survived"] == 1].head(5)`
# **SQL:** `SELECT * FROM passengers WHERE survived = 1 LIMIT 5`

# %%
# Завдання 3.1: Порівняння pandas та SQL

# %% [markdown]
# ### Завдання 3.2
#
# Закрийте з'єднання.

# %%
# Завдання 3.2
conn.close()
print("З'єднання закрито!")
