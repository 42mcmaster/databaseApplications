# %% [markdown]
# # dbAppsUA08 DIY Завдання: Створення та керування даними
#
# Створіть базу даних для невеликого бізнесу (магазин, кав'ярня, або інше на ваш вибір).

# %%
# Налаштування
import pandas as pd
import sqlite3

conn = sqlite3.connect("my_business.db")
print("Підключено!")

# %% [markdown]
# ## Частина 1: Створення таблиць
#
# ### Завдання 1.1
#
# Створіть 2 таблиці для вашого бізнесу. Мінімум вимоги:
# - Кожна таблиця має PRIMARY KEY
# - Мінімум 1 NOT NULL обмеження
# - Мінімум 1 CHECK або DEFAULT обмеження
# - Мінімум 1 FOREIGN KEY між таблицями

# %%
# Завдання 1.1: CREATE TABLE

# %% [markdown]
# ### Завдання 1.2
#
# Вставте мінімум 5 записів у кожну таблицю. Перевірте з SELECT.

# %%
# Завдання 1.2: INSERT та перевірка

# %% [markdown]
# ## Частина 2: UPDATE та DELETE
#
# ### Завдання 2.1
#
# Оновіть 2 записи використовуючи test-first підхід (SELECT → UPDATE → SELECT).

# %%
# Завдання 2.1: UPDATE з test-first

# %% [markdown]
# ### Завдання 2.2
#
# Видаліть 1 запис використовуючи test-first підхід.

# %%
# Завдання 2.2: DELETE з test-first

# %% [markdown]
# ## Частина 3: Запити
#
# ### Завдання 3.1
#
# Напишіть 3 різних SQL запити до вашої бази даних:
# 1. SELECT з WHERE
# 2. JOIN між вашими двома таблицями
# 3. GROUP BY з агрегатною функцією

# %%
# Завдання 3.1: Запит 1

# %%
# Завдання 3.1: Запит 2

# %%
# Завдання 3.1: Запит 3

# %% [markdown]
# ## Частина 4: Словник
#
# **CREATE TABLE:** ___
#
# **INSERT INTO:** ___
#
# **UPDATE:** ___
#
# **DELETE FROM:** ___
#
# **NOT NULL:** ___
#
# **FOREIGN KEY:** ___

# %%
conn.close()
print("З'єднання закрито!")
