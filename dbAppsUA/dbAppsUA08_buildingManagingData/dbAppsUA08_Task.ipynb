# %% [markdown]
# # dbAppsUA08 Завдання: Створення та керування даними
#
# **Урок:** 08 — CREATE, INSERT, UPDATE, DELETE, обмеження

# %%
# Налаштування
import pandas as pd
import sqlite3

conn = sqlite3.connect("task_practice.db")
print("Підключено!")

# %% [markdown]
# ## Завдання 1: CREATE TABLE
#
# Створіть таблицю `products` зі стовпцями:
# - productId INTEGER PRIMARY KEY
# - productName TEXT NOT NULL
# - price REAL CHECK(price > 0)
# - category TEXT DEFAULT 'General'
# - inStock INTEGER DEFAULT 1

# %%
# Завдання 1

# %% [markdown]
# ## Завдання 2: INSERT
#
# Вставте 5 записів товарів у таблицю `products`. Перевірте з SELECT.

# %%
# Завдання 2

# %% [markdown]
# ## Завдання 3: UPDATE (test-first)
#
# Оновіть ціну одного товару. Спочатку перевірте з SELECT, потім UPDATE, потім знову SELECT.

# %%
# Завдання 3: КРОК 1 - SELECT для перевірки

# %%
# Завдання 3: КРОК 2 - UPDATE

# %%
# Завдання 3: КРОК 3 - SELECT для підтвердження

# %% [markdown]
# ## Завдання 4: DELETE (test-first)
#
# Видаліть один товар. Спочатку перевірте з SELECT, потім DELETE, потім знову SELECT.

# %%
# Завдання 4: КРОК 1 - SELECT

# %%
# Завдання 4: КРОК 2 - DELETE

# %%
# Завдання 4: КРОК 3 - SELECT для підтвердження

# %% [markdown]
# ## Завдання 5: FOREIGN KEY
#
# Створіть таблицю `orders` зі стовпцями:
# - orderId INTEGER PRIMARY KEY
# - productId INTEGER (FOREIGN KEY → products)
# - quantity INTEGER NOT NULL
# - orderDate TEXT
#
# Вставте 3 записи замовлень.

# %%
# Завдання 5

# %%
conn.close()
print("З'єднання закрито!")
