# %% [markdown]
# # Lesson 06 Walkthrough: Database Design & Normalization
#
# **Course:** Database Applications Development
# **Lesson:** 06 - Database Design and Normalization
#
# ---
#
# ## Learning Objectives
#
# In this walkthrough, we will:
# 1. Analyze the NBA database structure
# 2. Verify normalization of our tables
# 3. Identify primary and foreign keys
# 4. Examine relationships between tables
# 5. Practice identifying normalization violations
# 6. Fix poorly designed tables
#
# **Skills practiced:**
# - Database analysis
# - Normalization principles (1NF, 2NF, 3NF)
# - Table design
# - Identifying relationships

# %% [markdown]
# ---
#
# ## Setup

# %%
import pandas as pd
import sqlite3

# Connect to database
conn = sqlite3.connect('nba_5seasons.db')
print("✅ Connected to NBA database")
# Out:
# ✅ Connected to NBA database

# %% [markdown]
# ---
#
# ## Part 1: Examining Database Structure
#
# Let's start by looking at what tables we have and their schemas.

# %% [markdown]
# ### Step 1.1: List All Tables

# %%
# TODO: Write a query to show all tables in the database
# Hint: SELECT name FROM sqlite_master WHERE type='table'
query = """
SELECT name 
FROM sqlite_master
WHERE type = 'table';
"""

tables = pd.read_sql(query, conn)
print("Tables in our NBA database:")
print(tables)
# Out:
# Tables in our NBA database:
#                   name
# 0                teams
# 1              players
# 2      team_game_stats
# 3  player_season_stats

# %% [markdown]
# **Question:** How many tables are in our database?
#
# **Your answer:**

# %% [markdown]
# ### Step 1.2: Examine teams Table Structure

# %%
# TODO: Get schema for `teams` table using PRAGMA table_info()
query = """
PRAGMA table_info(teams);
"""
teams_schema = pd.read_sql(query, conn)
print("teams table schema:")
print(teams_schema)
# Out:
# teams table schema:
#    cid          name     type  notnull dflt_value  pk
# 0    0       team_id  INTEGER        0       None   1
# 1    1     full_name     TEXT        0       None   0
# 2    2  abbreviation     TEXT        0       None   0
# 3    3      nickname     TEXT        0       None   0
# 4    4          city     TEXT        0       None   0
# 5    5         state     TEXT        0       None   0
# 6    6  year_founded  INTEGER        0       None   0

# %%
# Look at sample data
query = """
SELECT * 
FROM teams 
LIMIT 5;
"""

teams_sample = pd.read_sql(query, conn)
print("\nSample teams data:")
print(teams_sample)
# Out:
# Sample teams data:
#       team_id             full_name abbreviation   nickname         city  \
# 0  1610612737         Atlanta Hawks          ATL      Hawks      Atlanta
# 1  1610612738        Boston Celtics          BOS    Celtics       Boston
# 2  1610612739   Cleveland Cavaliers          CLE  Cavaliers    Cleveland
# 3  1610612740  New Orleans Pelicans          NOP   Pelicans  New Orleans
# 4  1610612741         Chicago Bulls          CHI      Bulls      Chicago
#
#            state  year_founded
# 0        Georgia          1949
# 1  Massachusetts          1946
# 2           Ohio          1970
# 3      Louisiana          2002
# 4       Illinois          1966

# %% [markdown]
# **Questions to discuss:**
#
# 1. What is the primary key of the teams table?
#
# **Your answer:**
#
# 2. Why is team_id a better primary key than full_name?
#
# **Your answer:**
#
# 3. Are all values in the teams table atomic (indivisible)?
#
# **Your answer:**
#
# 4. What normal form is this table in?
#
# **Your answer:**

# %% [markdown]
# ### Step 1.3: Examine players Table Structure

# %%
# TODO: Get schema for players table
query = """
PRAGMA table_info(players);
"""
players_schema = pd.read_sql(query, conn)
print("players table schema:")
print(players_schema)
# Out:
# players table schema:
#    cid       name     type  notnull dflt_value  pk
# 0    0  player_id  INTEGER        0       None   1
# 1    1  full_name     TEXT        0       None   0

# %%
# Look at sample data
query = """
SELECT * 
FROM players 
LIMIT 5
"""

players_sample = pd.read_sql(query, conn)
print("\nSample players data:")
print(players_sample)
# Out:
# Sample players data:
#    player_id        full_name
# 0       2207      Joe Johnson
# 1       2544     LeBron James
# 2       2546  Carmelo Anthony
# 3       2617    Udonis Haslem
# 4       2730    Dwight Howard

# %% [markdown]
# **Critical Question:**
#
# Why is there NO team_id column in the players table?
#
# **Your answer:**
#
# **Hint:** Think about what happens when a player gets traded to a different team.

# %% [markdown]
# ### Step 1.4: Examine team_game_stats Table Structure

# %%
# TODO: Get schema for team_game_stats table
query = """
PRAGMA table_info(team_game_stats);
"""
tgs_schema = pd.read_sql(query, conn)
print("team_game_stats table schema:")
print(tgs_schema)
# Out:
# team_game_stats table schema:
#     cid        name     type  notnull dflt_value  pk
# 0     0      season     TEXT        0       None   1
# 1     1     game_id     TEXT        0       None   2
# 2     2     team_id  INTEGER        0       None   3
# 3     3   game_date     TEXT        0       None   0
# 4     4     matchup     TEXT        0       None   0
# 5     5          wl     TEXT        0       None   0
# 6     6         pts  INTEGER        0       None   0
# 7     7         fgm  INTEGER        0       None   0
# 8     8         fga  INTEGER        0       None   0
# 9     9        fg3m  INTEGER        0       None   0
# 10   10        fg3a  INTEGER        0       None   0
# 11   11         ftm  INTEGER        0       None   0
# 12   12         fta  INTEGER        0       None   0
# 13   13        oreb  INTEGER        0       None   0
# 14   14        dreb  INTEGER        0       None   0
# 15   15         reb  INTEGER        0       None   0
# 16   16         ast  INTEGER        0       None   0
# 17   17         stl  INTEGER        0       None   0
# 18   18         blk  INTEGER        0       None   0
# 19   19         tov  INTEGER        0       None   0
# 20   20  plus_minus  INTEGER        0       None   0

# %%
# Look at sample data
query = """
SELECT * 
FROM team_game_stats 
LIMIT 5
"""

tgs_sample = pd.read_sql(query, conn)
print("\nSample team_game_stats data:")
print(tgs_sample)
# Out:
# Sample team_game_stats data:
#     season     game_id     team_id   game_date      matchup wl  pts  fgm  fga  \
# 0  2021-22  0022100002  1610612744  2021-10-19    GSW @ LAL  W  121   41   93
# 1  2021-22  0022100001  1610612751  2021-10-19    BKN @ MIL  L  104   37   84
# 2  2021-22  0022100002  1610612747  2021-10-19  LAL vs. GSW  L  114   45   95
# 3  2021-22  0022100001  1610612749  2021-10-19  MIL vs. BKN  W  127   48  105
# 4  2021-22  0022100007  1610612739  2021-10-20    CLE @ MEM  L  121   47   93
#
#    fg3m  ...  ftm  fta  oreb  dreb  reb  ast  stl  blk  tov  plus_minus
# 0    14  ...   25   30     9    41   50   30    9    2   17           7
# 1    17  ...   13   23     5    39   44   19    3    9   13         -23
# 2    15  ...    9   19     5    40   45   21    7    4   18          -7
# 3    17  ...   14   18    13    41   54   25    8    9    8          23
# 4    14  ...   13   18     7    29   36   38    6    5   11         -11
#
# [5 rows x 21 columns]

# %% [markdown]
# **Questions to discuss:**
#
# 1. What is the primary key? Is it a single column or composite?
#
# **Your answer:**
#
# 2. Why do we need BOTH game_id and team_id for the primary key?
#
# **Your answer:**
#
# 3. What foreign key(s) does this table have?
#
# **Your answer:**
#
# 4. Do all the statistics columns (pts, wl, etc.) depend on the entire primary key?
#
# **Your answer:**

# %% [markdown]
# ### Step 1.5: Examine player_season_stats Table Structure

# %%
# TODO: Get schema for player_season_stats table
query = """
PRAGMA table_info(player_season_stats);
"""

pss_schema = pd.read_sql(query, conn)
print("player_season_stats table schema:")
print(pss_schema)
# Out:
# player_season_stats table schema:
#     cid       name     type  notnull dflt_value  pk
# 0     0     season     TEXT        0       None   1
# 1     1  player_id  INTEGER        0       None   2
# 2     2    team_id  INTEGER        0       None   3
# 3     3         gp  INTEGER        0       None   0
# 4     4        min     REAL        0       None   0
# 5     5        pts     REAL        0       None   0
# 6     6        reb     REAL        0       None   0
# 7     7        ast     REAL        0       None   0
# 8     8        stl     REAL        0       None   0
# 9     9        blk     REAL        0       None   0
# 10   10        tov     REAL        0       None   0
# 11   11     fg_pct     REAL        0       None   0
# 12   12    fg3_pct     REAL        0       None   0
# 13   13     ft_pct     REAL        0       None   0

# %%
# Look at sample data
query = "SELECT * FROM player_season_stats LIMIT 5"
pss_sample = pd.read_sql(query, conn)
print("\nSample player_season_stats data:")
print(pss_sample)

# %% [markdown]
# **Questions to discuss:**
#
# 1. What columns make up the primary key?
#
# **Your answer:**
#
# 2. Why do we need ALL THREE columns (player_id, team_id, season) for uniqueness?
#
# **Your answer:**
#
# 3. What foreign keys does this table have?
#
# **Your answer:**
#
# 4. Is this table serving as a junction table? If so, what relationship does it create?
#
# **Your answer:**

# %% [markdown]
# ---
#
# ## Part 2: Identifying Relationships
#
# Let's verify the relationships between our tables.

# %% [markdown]
# ### Relationship 1: teams ↔ team_game_stats

# %% [markdown]
# ### Goal: Find how many games each team played in the 2021–22 season
#
# Work through the query step by step:
#
# 1. **SELECT**
#    - Choose the column that shows the team’s full name
#    - Count how many game rows belong to each team
#    - Give the count a clear alias
#
# 2. **FROM**
#    - Start with the table that stores team information
#    - Give it a short alias
#
# 3. **JOIN**
#    - Join the table that stores game-level statistics
#    - Match the two tables using the team ID
#
# 4. **WHERE**
#    - Filter the data to only include the **2021–22 season**
#
# 5. **GROUP BY**
#    - Group rows so each team appears **once**
#    - Include both the team ID and team name
#
# 6. **ORDER BY**
#    - Sort teams from **most games played to fewest**
#
# 7. **LIMIT**
#    - Show only the **top 5 teams**

# %%
# TODO: Count how many games each team has in the 2021-22 season
# This will show us the 1:M relationship
query = """
SELECT
    t.__________ AS team,            -- team full name
    COUNT(*) AS ___________          -- count of games
FROM _____ t                         -- teams table
JOIN _____________ tgs
    ON t._______ = tgs._______       -- match team IDs
WHERE tgs.season = '________'        -- season filter
GROUP BY t._______, t.__________     -- one row per team
ORDER BY ___________ DESC            -- most games first
LIMIT _;                             -- top N teams
"""

result = pd.read_sql(query, conn)
print("Games per team (2021-22 season):")
print(result)

# %% [markdown]
# **Question:** What type of relationship is this (1:1, 1:M, or M:N)?
#
# **Your answer:**

# %% [markdown]
# ### Relationship 2: Find players who changed teams

# %% [markdown]
# ### Goal: Find how many player-seasons each team had in the 2021–22 season
#
# Work through the query step by step:
#
# 1. **SELECT**
#    - Choose the column that shows the team’s full name
#    - Count how many player-season records belong to each team
#    - Give the count a clear alias
#
# 2. **FROM**
#    - Start with the table that stores team information
#    - Give it a short alias
#
# 3. **JOIN**
#    - Join the table that stores **player-season statistics**
#    - Match the two tables using the team ID
#
# 4. **WHERE**
#    - Filter the data to only include the **2021–22 season**
#
# 5. **GROUP BY**
#    - Group rows so each team appears **once**
#    - Include both the team ID and team name
#
# 6. **ORDER BY**
#    - Sort teams from **most player-seasons to fewest**
#
# 7. **LIMIT**
#    - Show only the **top 5 teams**

# %%
# This query shows the M:N relationship between players and teams
query = """
SELECT
    t.__________ AS team,               -- team full name
    COUNT(*) AS _____________           -- number of player-seasons
FROM _____ t                            -- teams table
JOIN __________________ pss
    ON t._______ = pss._______          -- match team IDs
WHERE pss.season = '________'           -- season filter
GROUP BY t._______, t.__________         -- one row per team
ORDER BY _____________ DESC              -- most player-seasons first
LIMIT _;                                -- top N teams
"""

result = pd.read_sql(query, conn)
print("Players who changed teams in 2021-22:")
print(result)

# %% [markdown]
# **Question:** This demonstrates what type of relationship between players and teams?
#
# **Your answer:**
#
# **Question:** What table serves as the junction table for this M:N relationship?
#
# **Your answer:**

# %% [markdown]
# ---
#
# ## Part 3: Normalization Practice
#
# Let's practice identifying and fixing normalization violations.

# %% [markdown]
# ### Example 1: Violating 1NF
#
# **BAD Design:**
# ```
# Players_Bad:
# player_id | name          | positions
# 1         | LeBron James  | SF, PF
# 2         | Stephen Curry | PG, SG
# ```

# %%
# Create the BAD table (for demonstration)
query = """
CREATE TABLE IF NOT EXISTS players_bad (
    player_id INTEGER PRIMARY KEY,
    name TEXT,
    positions TEXT
)
"""
conn.execute(query)

query = """
INSERT OR REPLACE INTO players_bad VALUES
    (1, 'LeBron James', 'SF, PF'),
    (2, 'Stephen Curry', 'PG, SG')
"""
conn.execute(query)
conn.commit()

print("BAD Design (violates 1NF):")
print(pd.read_sql("SELECT * FROM players_bad", conn))

# %% [markdown]
# **Question:** Why does this violate 1NF?
#
# **Your answer:**
#
# **Question:** How would you fix this design?
#
# **Your answer:**

# %% [markdown]
# ### Example 2: Violating 3NF
#
# **BAD Design:**
# ```
# Player_Stats:
# player_id | player_name | team_id | team_name     | team_city
# 1         | LeBron      | 1610612747 | Lakers     | Los Angeles
# 2         | Curry       | 1610612744 | Warriors   | San Francisco
# ```

# %%
# Create BAD table
query = """
CREATE TABLE IF NOT EXISTS player_stats_bad (
    player_id INTEGER PRIMARY KEY,
    player_name TEXT,
    team_id INTEGER,
    team_name TEXT,
    team_city TEXT
)
"""
conn.execute(query)

query = """
INSERT OR REPLACE INTO player_stats_bad VALUES
    (1, 'LeBron James', 1610612747, 'Los Angeles Lakers', 'Los Angeles'),
    (2, 'Anthony Davis', 1610612747, 'Los Angeles Lakers', 'Los Angeles'),
    (3, 'Stephen Curry', 1610612744, 'Golden State Warriors', 'San Francisco')
"""
conn.execute(query)
conn.commit()

print("BAD Design (violates 3NF):")
print(pd.read_sql("SELECT * FROM player_stats_bad", conn))

# %% [markdown]
# **Question:** What's wrong with this design? (Hint: Look at the Lakers players)
#
# **Your answer:**
#
# **Question:** What is the transitive dependency?
#
# **Your answer:**
#
# **Question:** What problems could this cause?
#
# **Your answer:**

# %% [markdown]
# ---
#
# ## Part 4: Your Analysis
#
# Based on what you've learned, answer these summary questions:

# %% [markdown]
# **1. Is our NBA database well-designed? Why or why not?**
#
# **Your answer:**
#
# **2. What normal form are our tables in?**
#
# **Your answer:**
#
# **3. Why does player_season_stats need a composite primary key with three columns?**
#
# **Your answer:**
#
# **4. Give one advantage of our database design:**
#
# **Your answer:**

# %% [markdown]
# ---
#
# ## Cleanup

# %%
# Clean up demonstration tables
conn.execute("DROP TABLE IF EXISTS players_bad")
conn.execute("DROP TABLE IF EXISTS player_stats_bad")
conn.commit()

# Close connection
conn.close()
print("✅ Walkthrough complete!")

# %% [markdown]
# ---
#
# ## Next Steps
#
# Now that you understand our NBA database structure, you're ready to:
# - Complete the task notebooks
# - Practice designing your own databases
# - Fix poorly designed tables
# - Create ERD diagrams
#
# **Good database design makes everything else easier!**
