# %% [markdown]
# # Lesson 06 Tasks - Part 2: Database Design Practice
#
# ## Database Applications Development
#
# **Objective:** Design normalized databases from scratch and analyze real-world scenarios.
#
# ### Instructions:
# - Complete ALL tasks in this notebook
# - Design tables, identify keys, and explain relationships
# - Use the NBA database as reference
# - Submit via GitHub (link only, no names in files)
#
# ### Grading:
# - Part 2: 50 points
# - All tasks must be attempted for full credit
# - Focus on clear explanations and correct relationships
#
# **Let's design some databases!**

# %% [markdown]
# ## Setup: Import Libraries and Connect

# %%
import sqlite3
import pandas as pd

# Connect to NBA database (for reference)
conn = sqlite3.connect('nba_5seasons.db')
print("✅ Connected to NBA database!")

# %% [markdown]
# ---
# ## Task 1: Analyze NBA Database Design (10 points)
#
# Study the NBA database structure and relationships.

# %% [markdown]
# ### Task 1a: Document table relationships
#
# Create a simple ERD (text format is fine) showing the four NBA tables and their relationships.

# %% [markdown]
# **NBA Database ERD:**
#
# ```
# <!-- Draw your ERD here in text format -->
# <!-- Example format:
# ┌─────────┐
# │ players │
# │─────────│
# │ PK: player_id
# │ full_name
# └─────────┘
#      │
#      │ (show relationships with arrows)
#      ▼
# [Add other tables...]
# -->
# ```

# %% [markdown]
# ### Task 1b: Identify relationship types
#
# **Question:** For each relationship in the NBA database, identify if it's 1:1, 1:M, or M:N:
#
# 1. teams → team_game_stats: <!-- Type? -->
# 2. players → player_season_stats: <!-- Type? -->
# 3. players ↔ teams (through player_season_stats): <!-- Type? -->
#
# **Explain your reasoning:**
# <!-- Explain here -->

# %% [markdown]
# ### Task 1c: Query to demonstrate M:N relationship
#
# Write a query showing one player who has played for multiple teams over their career.

# %%
# Show a player's career across multiple teams
query = """

"""

result = pd.read_sql(query, conn)
print(result)

# %% [markdown]
# ---
# ## Task 2: Design a School Database (15 points)
#
# Design a normalized database for a school system.

# %% [markdown]
# ### Task 2a: Identify entities
#
# **Scenario:** You need to track students, teachers, courses, and enrollments.
#
# **Question:** What tables (entities) do you need?
#
# **Your Answer:**
# 1. <!-- Table 1 -->
# 2. <!-- Table 2 -->
# 3. <!-- Table 3 -->
# 4. <!-- Table 4 -->

# %% [markdown]
# ### Task 2b: Design the students table
#
# Create a table definition for students. Include:
# - Primary key
# - At least 4 other columns
# - Appropriate data types
# - Constraints
#
# ```sql
# CREATE TABLE students (
#     -- Your table definition here
#
# );
# ```

# %% [markdown]
# ### Task 2c: Design the courses table
#
# ```sql
# CREATE TABLE courses (
#     -- Your table definition here
#
# );
# ```

# %% [markdown]
# ### Task 2d: Design the enrollments table (junction table)
#
# **Question:** Why do you need an enrollments table? What relationship does it create?
#
# **Your Answer:**
# <!-- Explain here -->
#
# ```sql
# CREATE TABLE enrollments (
#     -- Your table definition here
#     -- Include foreign keys!
#
# );
# ```

# %% [markdown]
# ### Task 2e: Draw school database ERD
#
# **School Database ERD:**
#
# ```
# <!-- Draw your ERD showing all tables and relationships -->
# ```

# %% [markdown]
# ---
# ## Task 3: Normalize a Denormalized Table (15 points)
#
# Fix a poorly designed table.

# %% [markdown]
# ### Task 3a: Identify violations
#
# **Given this denormalized table:**
#
# ```
# order_id | customer_name | customer_email | customer_phone | product1 | product2 | product3 | order_date | total
# ---------|---------------|----------------|----------------|----------|----------|----------|------------|------
# 1001     | John Smith    | john@email.com | 555-0100      | Laptop   | Mouse    | NULL     | 2024-01-15 | 850.00
# 1002     | Jane Doe      | jane@email.com | 555-0200      | Keyboard | NULL     | NULL     | 2024-01-16 | 75.00
# ```
#
# **Question:** What normal form violations do you see? List at least 3 problems.
#
# **Your Answer:**
# 1. <!-- Problem 1 -->
# 2. <!-- Problem 2 -->
# 3. <!-- Problem 3 -->

# %% [markdown]
# ### Task 3b: Design normalized tables
#
# Redesign this as normalized tables. You'll need at least 3 tables:
#
# ```sql
# -- Table 1: Customers
# CREATE TABLE customers (
#     -- Your definition here
# );
#
# -- Table 2: Products
# CREATE TABLE products (
#     -- Your definition here
# );
#
# -- Table 3: Orders
# CREATE TABLE orders (
#     -- Your definition here
# );
#
# -- Table 4: Order Items (junction table)
# CREATE TABLE order_items (
#     -- Your definition here
# );
# ```

# %% [markdown]
# ### Task 3c: Explain improvements
#
# **Question:** How does your normalized design solve the problems you identified in Task 3a?
#
# **Your Answer:**
# <!-- Explain the benefits of your normalized design -->

# %% [markdown]
# ---
# ## Task 4: Real-World Design Challenge (10 points)
#
# Design a database for a new scenario.

# %% [markdown]
# ### Task 4: Library Database Design
#
# **Scenario:** Design a database for a library system that tracks:
# - Books (title, author, ISBN, publication year)
# - Patrons (library card holders)
# - Checkouts (which patron has which book, when checked out, when due)
# - Authors (one book can have multiple authors!)
#
# **Your Design:**
#
# ```sql
# -- List all tables you need:
# -- 1.
# -- 2.
# -- 3.
# -- 4.
# -- 5. (if needed)
#
# -- Create table statements:
# CREATE TABLE _____  (
#     -- Your tables here
# );
# ```
#
# **ERD:**
# ```
# <!-- Draw your library database ERD -->
# ```
#
# **Explain:**
# - **Primary keys:** <!-- List them -->
# - **Foreign keys:** <!-- List them -->
# - **Junction tables (if any):** <!-- Explain why needed -->

# %% [markdown]
# ---
# ## Task 5: Reflection Questions (Bonus +5 points)
#
# Answer these conceptual questions.

# %% [markdown]
# ### Task 5a: When to denormalize
#
# **Question:** Give a real-world example where you might intentionally denormalize data (break normal form rules). Explain why.
#
# **Your Answer:**
# <!-- Example and explanation -->

# %% [markdown]
# ### Task 5b: Composite keys in real life
#
# **Question:** Besides our NBA database, give another example where a composite primary key would be needed. Explain what the columns would be and why you need all of them.
#
# **Your Answer:**
# <!-- Example and explanation -->

# %% [markdown]
# ### Task 5c: Database design mistakes
#
# **Question:** What do you think is the WORST database design mistake you could make? Explain why it would be so bad.
#
# **Your Answer:**
# <!-- Your thoughtful response -->

# %% [markdown]
# ---
# ## Submission
#
# 1. **Save this notebook**
# 2. **Upload to your GitHub repository**
# 3. **Submit the GitHub link** (not the file)
# 4. **Do NOT include your name in the filename**
#
# ### Before submitting, verify:
# - [ ] All tasks attempted
# - [ ] All table definitions include primary keys
# - [ ] Foreign keys are clearly identified
# - [ ] ERDs show relationships between tables
# - [ ] Explanations are clear and complete
#
# **Excellent work completing Lesson 06 tasks!** 🎉

# %%
# Close connection
conn.close()
print("✅ Connection closed. Part 2 complete!")
